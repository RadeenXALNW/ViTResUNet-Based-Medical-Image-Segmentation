# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import random
import h5py
import numpy as np
import torch
from scipy import ndimage
from scipy.ndimage.interpolation import zoom
from torch.utils.data import Dataset


def random_rot_flip(image, label):
    k = np.random.randint(0, 4)
    image = np.rot90(image, k)
    label = np.rot90(label, k)
    axis = np.random.randint(0, 2)
    image = np.flip(image, axis=axis).copy()
    label = np.flip(label, axis=axis).copy()
    return image, label


def random_rotate(image, label):
    angle = np.random.randint(-20, 20)
    image = ndimage.rotate(image, angle, order=0, reshape=False)
    label = ndimage.rotate(label, angle, order=0, reshape=False)
    return image, label


class RandomGenerator(object):
    def __init__(self, output_size):
        self.output_size = output_size

    def __call__(self, sample):
        image, label = sample['image'], sample['label']

        if random.random() > 0.5:
            image, label = random_rot_flip(image, label)
        elif random.random() > 0.5:
            image, label = random_rotate(image, label)
        x, y = image.shape
        if x != self.output_size[0] or y != self.output_size[1]:
            image = zoom(image, (self.output_size[0] / x, self.output_size[1] / y), order=3)  # why not 3?
            label = zoom(label, (self.output_size[0] / x, self.output_size[1] / y), order=0)
        image = torch.from_numpy(image.astype(np.float32)).unsqueeze(0)
        label = torch.from_numpy(label.astype(np.float32))
        sample = {'image': image, 'label': label.long()}
        return sample


class Synapse_dataset(Dataset):
    def __init__(self, base_dir, list_dir, split, transform=None):
        self.transform = transform  # using transform in torch!
        self.split = split
        self.sample_list = open(os.path.join(list_dir, self.split+'.txt')).readlines()
        self.data_dir = base_dir

    def __len__(self):
        return len(self.sample_list)

    def __getitem__(self, idx):
        if self.split == "train":
            slice_name = self.sample_list[idx].strip('\n')
            data_path = os.path.join(self.data_dir, slice_name+'.npz')
            data = np.load(data_path)
            image, label = data['image'], data['label']
        else:
            vol_name = self.sample_list[idx].strip('\n')
            filepath = self.data_dir + "/{}.npy.h5".format(vol_name)
            data = h5py.File(filepath)
            image, label = data['image'][:], data['label'][:]

        sample = {'image': image, 'label': label}
        if self.transform:
            sample = self.transform(sample)
        sample['case_name'] = self.sample_list[idx].strip('\n')
        return sample

# %%
from os.path import join
from os.path import normpath
import platform

def pjoin(path, *paths):
    p = join(path, *paths)
    if platform.system() == "Windows":
        return normpath(p).replace('\\','/')
    else:
        return p

# %%
# !pip install ml_collections
# !pip install tensorboardX
# !pip install MedPy
# Out:
# Requirement already satisfied: ml_collections in /usr/local/lib/python3.7/dist-packages (0.1.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from ml_collections) (1.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from ml_collections) (3.13)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.7/dist-packages (from ml_collections) (0.5.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from ml_collections) (1.15.0)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.7/dist-packages (2.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorboardX) (3.17.3)
# Requirement already satisfied: MedPy in /usr/local/lib/python3.7/dist-packages (0.4.0)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from MedPy) (1.21.6)
# Requirement already satisfied: SimpleITK>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from MedPy) (2.1.1.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from MedPy) (1.4.1)

# %%
# !pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.7/dist-packages (1.6.6)

# %%
import ml_collections
import torch.nn as nn


def get_b16_config():
    """Returns the ViT-B/16 configuration."""
    config = ml_collections.ConfigDict()
    config.patches = ml_collections.ConfigDict({'size': (16, 16)})
    config.hidden_size = 768
    config.transformer = ml_collections.ConfigDict()
    config.transformer.mlp_dim = 3072
    config.transformer.num_heads = 12
    config.transformer.num_layers = 12
    config.transformer.attention_dropout_rate = 0.0
    config.transformer.dropout_rate = 0.1

    config.classifier = 'seg'
    config.representation_size = None
    config.resnet_pretrained_path = None
    config.pretrained_path = '/content/gdrive/MyDrive/Synapse/imagenet21k+imagenet2012_ViT-B_16.npz'
    config.patch_size = 16

    config.decoder_channels = (256, 128, 64, 16)
    config.n_classes = 2
    config.activation = 'softmax'
    return config

def get_r50_b16_config():
    """Returns the Resnet50 + ViT-B/16 configuration."""
    config = get_b16_config()
    config.patches.grid = (8, 8)
    config.resnet = ml_collections.ConfigDict()
    config.resnet.num_layers = (3, 4, 9)
    config.resnet.width_factor = 1

    config.classifier = 'seg'
    config.pretrained_path = '/content/gdrive/MyDrive/Synapse/imagenet21k+imagenet2012_R50+ViT-B_16.npz'
    config.decoder_channels = (256, 128, 64, 16)
    config.skip_channels = [512, 256, 64, 16]
    config.n_classes = 2
    config.n_skip = 3
    config.activation = 'softmax'

    return config

# %%
class Flatten(nn.Module):
    def forward(self, x):
        return x.view(x.size(0), -1)


class ChannelAttention(nn.Module):
    def __init__(self, input_channels, reduction_ratio=16):
        super(ChannelAttention, self).__init__()
        self.input_channels = input_channels
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
        #  https://github.com/luuuyi/CBAM.PyTorch/blob/master/model/resnet_cbam.py
        #  uses Convolutions instead of Linear
        self.MLP = nn.Sequential(
            Flatten(),
            nn.Linear(input_channels, input_channels // reduction_ratio),
            nn.ReLU(),
            nn.Linear(input_channels // reduction_ratio, input_channels)
        )

    def forward(self, x):
        # Take the input and apply average and max pooling
        avg_values = self.avg_pool(x)
        max_values = self.max_pool(x)
        out = self.MLP(avg_values) + self.MLP(max_values)
        scale = x * torch.sigmoid(out).unsqueeze(2).unsqueeze(3).expand_as(x)
        return scale


class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1
        self.conv = nn.Conv2d(2, 1, kernel_size=kernel_size, padding=padding, bias=False)
        self.bn = nn.BatchNorm2d(1)

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        out = torch.cat([avg_out, max_out], dim=1)
        out = self.conv(out)
        out = self.bn(out)
        scale = x * torch.sigmoid(out)
        return scale


class CBAM(nn.Module):
    def __init__(self, input_channels, reduction_ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.channel_att = ChannelAttention(input_channels, reduction_ratio=reduction_ratio)
        self.spatial_att = SpatialAttention(kernel_size=kernel_size)

    def forward(self, x):
        out = self.channel_att(x)
        out = self.spatial_att(out)
        return out

# %%
from typing import Counter
import math

from collections import OrderedDict

import torch
import torch.nn as nn
import torch.nn.functional as F
from os.path import join
from os.path import normpath
import platform

def pjoin(path, *paths):
    p = join(path, *paths)
    if platform.system() == "Windows":
        return normpath(p).replace('\\','/')
    else:
        return p

def np2th(weights, conv=False):
    """Possibly convert HWIO to OIHW."""
    if conv:
        weights = weights.transpose([3, 2, 0, 1])
    return torch.from_numpy(weights)


class StdConv2d(nn.Conv2d):

    def forward(self, x):
        w = self.weight
        v, m = torch.var_mean(w, dim=[1, 2, 3], keepdim=True, unbiased=False)
        w = (w - m) / torch.sqrt(v + 1e-5)
        return F.conv2d(x, w, self.bias, self.stride, self.padding,
                        self.dilation, self.groups)


def conv3x3(cin, cout, stride=1, groups=1, bias=False):
    return StdConv2d(cin, cout, kernel_size=3, stride=stride,
                     padding=1, bias=bias, groups=groups)


def conv1x1(cin, cout, stride=1, bias=False):
    return StdConv2d(cin, cout, kernel_size=1, stride=stride,
                     padding=0, bias=bias)


class PreActBottleneck(nn.Module):
    """Pre-activation (v2) bottleneck block.
    """

    def __init__(self, cin, cout=None, cmid=None, stride=1):
        super().__init__()
        cout = cout or cin
        cmid = cmid or cout//4

        self.gn1 = nn.GroupNorm(32, cmid, eps=1e-6)
        self.conv1 = conv1x1(cin, cmid, bias=False)
        self.CBAM9 = CBAM(cmid)

        self.gn2 = nn.GroupNorm(32, cmid, eps=1e-6)
        self.conv2 = conv3x3(cmid, cmid, stride, bias=False)  # Original code has it on conv1!!
        self.CBAM6 = CBAM(cmid)

        self.gn3 = nn.GroupNorm(32, cout, eps=1e-6)
        self.conv3 = conv1x1(cmid, cout, bias=False)
        self.CBAM7 = CBAM(cout)

        self.CBAM8 = CBAM(cout)
        self.relu = nn.ReLU(inplace=True)

        if (stride != 1 or cin != cout):
            # Projection also with pre-activation according to paper.
            self.downsample = conv1x1(cin, cout, stride, bias=False)
            self.gn_proj = nn.GroupNorm(cout, cout)

    def forward(self, x):

        # Residual branch
        residual = x
        if hasattr(self, 'downsample'):
            residual = self.downsample(x)
            residual = self.gn_proj(residual)

        # Unit's branch
        # y=self.CBAM9(x)
        y = self.relu(self.gn1(self.conv1(x)))
        # print('y1', y.shape)
        y = self.CBAM9(y)

        y = self.relu(self.gn2(self.conv2(y)))
        # print("y2",y.shape)
        y = self.CBAM6(y)

        y = self.gn3(self.conv3(y))
        y = self.CBAM7(y)
        # print("y3",y.shape)

        y = self.relu(residual + y)
        y = self.CBAM8(y)
        # print("y4",y.shape)
        return y

    def load_from(self, weights, n_block, n_unit):
        conv1_weight = np2th(weights[pjoin(n_block, n_unit, "conv1/kernel")], conv=True)
        conv2_weight = np2th(weights[pjoin(n_block, n_unit, "conv2/kernel")], conv=True)
        conv3_weight = np2th(weights[pjoin(n_block, n_unit, "conv3/kernel")], conv=True)

        gn1_weight = np2th(weights[pjoin(n_block, n_unit, "gn1/scale")])
        gn1_bias = np2th(weights[pjoin(n_block, n_unit, "gn1/bias")])

        gn2_weight = np2th(weights[pjoin(n_block, n_unit, "gn2/scale")])
        gn2_bias = np2th(weights[pjoin(n_block, n_unit, "gn2/bias")])

        gn3_weight = np2th(weights[pjoin(n_block, n_unit, "gn3/scale")])
        gn3_bias = np2th(weights[pjoin(n_block, n_unit, "gn3/bias")])

        self.conv1.weight.copy_(conv1_weight)
        self.conv2.weight.copy_(conv2_weight)
        self.conv3.weight.copy_(conv3_weight)

        self.gn1.weight.copy_(gn1_weight.view(-1))
        self.gn1.bias.copy_(gn1_bias.view(-1))

        self.gn2.weight.copy_(gn2_weight.view(-1))
        self.gn2.bias.copy_(gn2_bias.view(-1))

        self.gn3.weight.copy_(gn3_weight.view(-1))
        self.gn3.bias.copy_(gn3_bias.view(-1))

        if hasattr(self, 'downsample'):
            proj_conv_weight = np2th(weights[pjoin(n_block, n_unit, "conv_proj/kernel")], conv=True)
            proj_gn_weight = np2th(weights[pjoin(n_block, n_unit, "gn_proj/scale")])
            proj_gn_bias = np2th(weights[pjoin(n_block, n_unit, "gn_proj/bias")])

            self.downsample.weight.copy_(proj_conv_weight)
            self.gn_proj.weight.copy_(proj_gn_weight.view(-1))
            self.gn_proj.bias.copy_(proj_gn_bias.view(-1))

class ResNetV2(nn.Module):
    """Implementation of Pre-activation (v2) ResNet mode."""

    def __init__(self, block_units, width_factor):
        super().__init__()
        width = int(64 * width_factor)
        self.width = width

        self.root = nn.Sequential(OrderedDict([
            ('conv', StdConv2d(3, width, kernel_size=7, stride=2, bias=False, padding=3)),
            ('gn', nn.GroupNorm(32, width, eps=1e-6)),
            ('relu', nn.ReLU(inplace=True)),
            # ('pool', nn.MaxPool2d(kernel_size=3, stride=2, padding=0))
        ]))

        self.body = nn.Sequential(OrderedDict([
            ('block1/', nn.Sequential(OrderedDict(
                [('unit1/', PreActBottleneck(cin=width, cout=width*4, cmid=width))] +
                [(f'unit{i:d}/', PreActBottleneck(cin=width*4, cout=width*4, cmid=width)) for i in range(2, block_units[0] + 1)],
                ))),
            ('block2/', nn.Sequential(OrderedDict(
                [('unit1/', PreActBottleneck(cin=width*4, cout=width*8, cmid=width*2, stride=2))] +
                [(f'unit{i:d}/', PreActBottleneck(cin=width*8, cout=width*8, cmid=width*2)) for i in range(2, block_units[1] + 1)],
                ))),
            ('block3/', nn.Sequential(OrderedDict(
                [('unit1/', PreActBottleneck(cin=width*8, cout=width*16, cmid=width*4, stride=2))] +
                [(f'unit{i:d}/', PreActBottleneck(cin=width*16, cout=width*16, cmid=width*4)) for i in range(2, block_units[2] + 1)],
                ))),
        ]))

    def forward(self, x):
        features = []
        b, c, in_size, _ = x.size()
        x = self.root(x)
        features.append(x)
        x = nn.MaxPool2d(kernel_size=3, stride=2, padding=0)(x)
        for i in range(len(self.body)-1):
            x = self.body[i](x)
            right_size = int(in_size / 4 / (i+1))
            if x.size()[2] != right_size:
                pad = right_size - x.size()[2]
                assert pad < 3 and pad > 0, "x {} should {}".format(x.size(), right_size)
                feat = torch.zeros((b, x.size()[1], right_size, right_size), device=x.device)
                feat[:, :, 0:x.size()[2], 0:x.size()[3]] = x[:]
            else:
                feat = x
            features.append(feat)
        x = self.body[-1](x)
        return x, features[::-1]

# %%
config = get_r50_b16_config()
resnet = ResNetV2(block_units=config.resnet.num_layers, width_factor=config.resnet.width_factor)

out = resnet(torch.zeros(1,3,224,224))
print(out[0].shape, len(out[1]))
print([y.shape for y in out[1]])
# Out:
# torch.Size([1, 1024, 14, 14]) 3
# [torch.Size([1, 512, 28, 28]), torch.Size([1, 256, 56, 56]), torch.Size([1, 64, 112, 112])]

# %%
# coding=utf-8
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import copy
import logging
import math


import torch
import torch.nn as nn
import numpy as np

from torch.nn import CrossEntropyLoss, Dropout, Softmax, Linear, Conv2d, LayerNorm
from torch.nn.modules.utils import _pair
from scipy import ndimage



logger = logging.getLogger(__name__)


ATTENTION_Q = "MultiHeadDotProductAttention_1/query/"
ATTENTION_K = "MultiHeadDotProductAttention_1/key/"
ATTENTION_V = "MultiHeadDotProductAttention_1/value/"
ATTENTION_OUT = "MultiHeadDotProductAttention_1/out/"
FC_0 = "MlpBlock_3/Dense_0/"
FC_1 = "MlpBlock_3/Dense_1/"
ATTENTION_NORM = "LayerNorm_0/"
MLP_NORM = "LayerNorm_2/"


def np2th(weights, conv=False):
    """Possibly convert HWIO to OIHW."""
    if conv:
        weights = weights.transpose([3, 2, 0, 1])
    return torch.from_numpy(weights)


def swish(x):
    return x * torch.sigmoid(x)


ACT2FN = {"gelu": torch.nn.functional.gelu, "relu": torch.nn.functional.relu, "swish": swish}


class Attention(nn.Module):
    def __init__(self, config, vis):
        super(Attention, self).__init__()
        self.vis = vis
        self.num_attention_heads = config.transformer["num_heads"]
        self.attention_head_size = int(config.hidden_size / self.num_attention_heads)
        self.all_head_size = self.num_attention_heads * self.attention_head_size

        self.query = Linear(config.hidden_size, self.all_head_size)
        self.key = Linear(config.hidden_size, self.all_head_size)
        self.value = Linear(config.hidden_size, self.all_head_size)

        self.out = Linear(config.hidden_size, config.hidden_size)
        self.attn_dropout = Dropout(config.transformer["attention_dropout_rate"])
        self.proj_dropout = Dropout(config.transformer["attention_dropout_rate"])

        self.softmax = Softmax(dim=-1)

    def transpose_for_scores(self, x):
        new_x_shape = x.size()[:-1] + (self.num_attention_heads, self.attention_head_size)
        x = x.view(*new_x_shape)
        return x.permute(0, 2, 1, 3)

    def forward(self, hidden_states):
        mixed_query_layer = self.query(hidden_states)
        mixed_key_layer = self.key(hidden_states)
        mixed_value_layer = self.value(hidden_states)

        query_layer = self.transpose_for_scores(mixed_query_layer)
        key_layer = self.transpose_for_scores(mixed_key_layer)
        value_layer = self.transpose_for_scores(mixed_value_layer)

        attention_scores = torch.matmul(query_layer, key_layer.transpose(-1, -2))
        attention_scores = attention_scores / math.sqrt(self.attention_head_size)
        attention_probs = self.softmax(attention_scores)
        weights = attention_probs if self.vis else None
        attention_probs = self.attn_dropout(attention_probs)

        context_layer = torch.matmul(attention_probs, value_layer)
        context_layer = context_layer.permute(0, 2, 1, 3).contiguous()
        new_context_layer_shape = context_layer.size()[:-2] + (self.all_head_size,)
        context_layer = context_layer.view(*new_context_layer_shape)
        attention_output = self.out(context_layer)
        attention_output = self.proj_dropout(attention_output)
        return attention_output, weights


class Mlp(nn.Module):
    def __init__(self, config):
        super(Mlp, self).__init__()
        self.fc1 = Linear(config.hidden_size, config.transformer["mlp_dim"])
        self.fc2 = Linear(config.transformer["mlp_dim"], config.hidden_size)
        self.act_fn = ACT2FN["gelu"]
        self.dropout = Dropout(config.transformer["dropout_rate"])

        self._init_weights()

    def _init_weights(self):
        nn.init.xavier_uniform_(self.fc1.weight)
        nn.init.xavier_uniform_(self.fc2.weight)
        nn.init.normal_(self.fc1.bias, std=1e-6)
        nn.init.normal_(self.fc2.bias, std=1e-6)

    def forward(self, x):
        x = self.fc1(x)
        x = self.act_fn(x)
        x = self.dropout(x)
        x = self.fc2(x)
        x = self.dropout(x)
        return x


class Embeddings(nn.Module):
    """Construct the embeddings from patch, position embeddings.
    """
    def __init__(self, config, img_size, in_channels=3):
        super(Embeddings, self).__init__()
        self.hybrid = None
        self.config = config
        img_size = _pair(img_size)

        if config.patches.get("grid") is not None:   # ResNet
            grid_size = config.patches["grid"]
            patch_size = (img_size[0] // 16 // grid_size[0], img_size[1] // 16 // grid_size[1])
            patch_size_real = (patch_size[0] * 16, patch_size[1] * 16)
            n_patches = (img_size[0] // patch_size_real[0]) * (img_size[1] // patch_size_real[1])  
            self.hybrid = True
        else:
            patch_size = _pair(config.patches["size"])
            n_patches = (img_size[0] // patch_size[0]) * (img_size[1] // patch_size[1])
            self.hybrid = False

        if self.hybrid:
            self.hybrid_model = ResNetV2(block_units=config.resnet.num_layers, width_factor=config.resnet.width_factor)
            in_channels = self.hybrid_model.width * 16
        self.patch_embeddings = Conv2d(in_channels=in_channels,
                                       out_channels=config.hidden_size,
                                       kernel_size=patch_size,
                                       stride=patch_size)
        self.position_embeddings = nn.Parameter(torch.zeros(1, n_patches, config.hidden_size))

        self.dropout = Dropout(config.transformer["dropout_rate"])


    def forward(self, x):
        if self.hybrid:
            x, features = self.hybrid_model(x)
        else:
            features = None
        x = self.patch_embeddings(x)  # (B, hidden. n_patches^(1/2), n_patches^(1/2))
        x = x.flatten(2)
        x = x.transpose(-1, -2)  # (B, n_patches, hidden)

        embeddings = x + self.position_embeddings
        embeddings = self.dropout(embeddings)
        return embeddings, features


class Block(nn.Module):
    def __init__(self, config, vis):
        super(Block, self).__init__()
        self.hidden_size = config.hidden_size
        self.attention_norm = LayerNorm(config.hidden_size, eps=1e-6)
        self.ffn_norm = LayerNorm(config.hidden_size, eps=1e-6)
        self.ffn = Mlp(config)
        self.attn = Attention(config, vis)

    def forward(self, x):
        h = x
        x = self.attention_norm(x)
        x, weights = self.attn(x)
        x = x + h

        h = x
        x = self.ffn_norm(x)
        x = self.ffn(x)
        x = x + h
        return x, weights

    def load_from(self, weights, n_block):
        ROOT = f"Transformer/encoderblock_{n_block}"
        with torch.no_grad():
            query_weight = np2th(weights[pjoin(ROOT, ATTENTION_Q, "kernel")]).view(self.hidden_size, self.hidden_size).t()
            key_weight = np2th(weights[pjoin(ROOT, ATTENTION_K, "kernel")]).view(self.hidden_size, self.hidden_size).t()
            value_weight = np2th(weights[pjoin(ROOT, ATTENTION_V, "kernel")]).view(self.hidden_size, self.hidden_size).t()
            out_weight = np2th(weights[pjoin(ROOT, ATTENTION_OUT, "kernel")]).view(self.hidden_size, self.hidden_size).t()

            query_bias = np2th(weights[pjoin(ROOT, ATTENTION_Q, "bias")]).view(-1)
            key_bias = np2th(weights[pjoin(ROOT, ATTENTION_K, "bias")]).view(-1)
            value_bias = np2th(weights[pjoin(ROOT, ATTENTION_V, "bias")]).view(-1)
            out_bias = np2th(weights[pjoin(ROOT, ATTENTION_OUT, "bias")]).view(-1)

            self.attn.query.weight.copy_(query_weight)
            self.attn.key.weight.copy_(key_weight)
            self.attn.value.weight.copy_(value_weight)
            self.attn.out.weight.copy_(out_weight)
            self.attn.query.bias.copy_(query_bias)
            self.attn.key.bias.copy_(key_bias)
            self.attn.value.bias.copy_(value_bias)
            self.attn.out.bias.copy_(out_bias)

            mlp_weight_0 = np2th(weights[pjoin(ROOT, FC_0, "kernel")]).t()
            mlp_weight_1 = np2th(weights[pjoin(ROOT, FC_1, "kernel")]).t()
            mlp_bias_0 = np2th(weights[pjoin(ROOT, FC_0, "bias")]).t()
            mlp_bias_1 = np2th(weights[pjoin(ROOT, FC_1, "bias")]).t()

            self.ffn.fc1.weight.copy_(mlp_weight_0)
            self.ffn.fc2.weight.copy_(mlp_weight_1)
            self.ffn.fc1.bias.copy_(mlp_bias_0)
            self.ffn.fc2.bias.copy_(mlp_bias_1)

            self.attention_norm.weight.copy_(np2th(weights[pjoin(ROOT, ATTENTION_NORM, "scale")]))
            self.attention_norm.bias.copy_(np2th(weights[pjoin(ROOT, ATTENTION_NORM, "bias")]))
            self.ffn_norm.weight.copy_(np2th(weights[pjoin(ROOT, MLP_NORM, "scale")]))
            self.ffn_norm.bias.copy_(np2th(weights[pjoin(ROOT, MLP_NORM, "bias")]))


class Encoder(nn.Module):
    def __init__(self, config, vis):
        super(Encoder, self).__init__()
        self.vis = vis
        self.layer = nn.ModuleList()
        self.encoder_norm = LayerNorm(config.hidden_size, eps=1e-6)
        for _ in range(config.transformer["num_layers"]):
            layer = Block(config, vis)
            self.layer.append(copy.deepcopy(layer))

    def forward(self, hidden_states):
        attn_weights = []
        for layer_block in self.layer:
            hidden_states, weights = layer_block(hidden_states)
            if self.vis:
                attn_weights.append(weights)
        encoded = self.encoder_norm(hidden_states)
        return encoded, attn_weights


class Transformer(nn.Module):
    def __init__(self, config, img_size, vis):
        super(Transformer, self).__init__()
        self.embeddings = Embeddings(config, img_size=img_size)
        self.encoder = Encoder(config, vis)

    def forward(self, input_ids):
        embedding_output, features = self.embeddings(input_ids)
        encoded, attn_weights = self.encoder(embedding_output)  # (B, n_patch, hidden)
        return encoded, attn_weights, features


class Conv2dReLU(nn.Sequential):
    def __init__(
            self,
            in_channels,
            out_channels,
            kernel_size,
            padding=0,
            stride=1,
            use_batchnorm=True,
    ):
        conv = nn.Conv2d(
            in_channels,
            out_channels,
            kernel_size,
            stride=stride,
            padding=padding,
            bias=not (use_batchnorm),
        )
        relu = nn.ReLU(inplace=True)

        bn = nn.BatchNorm2d(out_channels)

        super(Conv2dReLU, self).__init__(conv, bn, relu)


class DecoderBlock(nn.Module):
    def __init__(
            self,
            in_channels,
            out_channels,
            skip_channels=0,
            use_batchnorm=True,
    ):
        super().__init__()
        self.cbam1 = CBAM(in_channels)
        self.conv1 = Conv2dReLU(
            in_channels + skip_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.cbam2 = CBAM(in_channels+skip_channels)
        self.conv2 = Conv2dReLU(
            out_channels,
            out_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=use_batchnorm,
        )
        self.cbam3 = CBAM(out_channels)
        self.up = nn.UpsamplingBilinear2d(scale_factor=2)


    def forward(self, x, skip=None):
        x=self.cbam1(x)
        x = self.up(x)
        if skip is not None:
            x = torch.cat([x, skip], dim=1)
        x=self.cbam2(x)
        x = self.conv1(x)
        x = self.conv2(x)
        x=self.cbam3(x)
        return x


class SegmentationHead(nn.Sequential):

    def __init__(self, in_channels, out_channels, kernel_size=3, upsampling=1):
        conv2d = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, padding=kernel_size // 2)
        upsampling = nn.UpsamplingBilinear2d(scale_factor=upsampling) if upsampling > 1 else nn.Identity()
        super().__init__(conv2d, upsampling)


class DecoderCup(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        head_channels = 512
        self.conv_more = Conv2dReLU(
            config.hidden_size,
            head_channels,
            kernel_size=3,
            padding=1,
            use_batchnorm=True,
        )
        decoder_channels = config.decoder_channels
        in_channels = [head_channels] + list(decoder_channels[:-1])
        out_channels = decoder_channels

        if self.config.n_skip != 0:
            skip_channels = self.config.skip_channels
            for i in range(4-self.config.n_skip):  # re-select the skip channels according to n_skip
                skip_channels[3-i]=0

        else:
            skip_channels=[0,0,0,0]

        blocks = [
            DecoderBlock(in_ch, out_ch, sk_ch) for in_ch, out_ch, sk_ch in zip(in_channels, out_channels, skip_channels)
        ]
        self.blocks = nn.ModuleList(blocks)

    def forward(self, hidden_states, features=None):
        B, n_patch, hidden = hidden_states.size()  # reshape from (B, n_patch, hidden) to (B, h, w, hidden)
        h, w = int(np.sqrt(n_patch)), int(np.sqrt(n_patch))
        x = hidden_states.permute(0, 2, 1)
        x = x.contiguous().view(B, hidden, h, w)
        x = self.conv_more(x)
        for i, decoder_block in enumerate(self.blocks):
            if features is not None:
                skip = features[i] if (i < self.config.n_skip) else None
            else:
                skip = None
            x = decoder_block(x, skip=skip)
        return x


class VisionTransformer(nn.Module):
    def __init__(self, config, img_size=224, num_classes=21843, zero_head=False, vis=False):
        super(VisionTransformer, self).__init__()
        self.num_classes = num_classes
        self.zero_head = zero_head
        self.classifier = config.classifier
        self.transformer = Transformer(config, img_size, vis)
        self.decoder = DecoderCup(config)
        self.segmentation_head = SegmentationHead(
            in_channels=config['decoder_channels'][-1],
            out_channels=config['n_classes'],
            kernel_size=3,
        )
        self.config = config

    def forward(self, x):
        if x.size()[1] == 1:
            x = x.repeat(1,3,1,1)
        x, attn_weights, features = self.transformer(x)  # (B, n_patch, hidden)
        x = self.decoder(x, features)
        logits = self.segmentation_head(x)
        return logits

    def load_from(self, weights):
        with torch.no_grad():

            res_weight = weights
            self.transformer.embeddings.patch_embeddings.weight.copy_(np2th(weights["embedding/kernel"], conv=True))
            self.transformer.embeddings.patch_embeddings.bias.copy_(np2th(weights["embedding/bias"]))

            self.transformer.encoder.encoder_norm.weight.copy_(np2th(weights["Transformer/encoder_norm/scale"]))
            self.transformer.encoder.encoder_norm.bias.copy_(np2th(weights["Transformer/encoder_norm/bias"]))

            posemb = np2th(weights["Transformer/posembed_input/pos_embedding"])

            posemb_new = self.transformer.embeddings.position_embeddings
            if posemb.size() == posemb_new.size():
                self.transformer.embeddings.position_embeddings.copy_(posemb)
            elif posemb.size()[1]-1 == posemb_new.size()[1]:
                posemb = posemb[:, 1:]
                self.transformer.embeddings.position_embeddings.copy_(posemb)
            else:
                logger.info("load_pretrained: resized variant: %s to %s" % (posemb.size(), posemb_new.size()))
                ntok_new = posemb_new.size(1)
                if self.classifier == "seg":
                    _, posemb_grid = posemb[:, :1], posemb[0, 1:]
                gs_old = int(np.sqrt(len(posemb_grid)))
                gs_new = int(np.sqrt(ntok_new))
                print('load_pretrained: grid-size from %s to %s' % (gs_old, gs_new))
                posemb_grid = posemb_grid.reshape(gs_old, gs_old, -1)
                zoom = (gs_new / gs_old, gs_new / gs_old, 1)
                posemb_grid = ndimage.zoom(posemb_grid, zoom, order=1)  # th2np
                posemb_grid = posemb_grid.reshape(1, gs_new * gs_new, -1)
                posemb = posemb_grid
                self.transformer.embeddings.position_embeddings.copy_(np2th(posemb))

            # Encoder whole
            for bname, block in self.transformer.encoder.named_children():
                for uname, unit in block.named_children():
                    unit.load_from(weights, n_block=uname)

            if self.transformer.embeddings.hybrid:
                self.transformer.embeddings.hybrid_model.root.conv.weight.copy_(np2th(res_weight["conv_root/kernel"], conv=True))
                gn_weight = np2th(res_weight["gn_root/scale"]).view(-1)
                gn_bias = np2th(res_weight["gn_root/bias"]).view(-1)
                self.transformer.embeddings.hybrid_model.root.gn.weight.copy_(gn_weight)
                self.transformer.embeddings.hybrid_model.root.gn.bias.copy_(gn_bias)

                for bname, block in self.transformer.embeddings.hybrid_model.body.named_children():
                    for uname, unit in block.named_children():
                        unit.load_from(res_weight, n_block=bname, n_unit=uname)
                        
CONFIGS = {
#     'ViT-B_32': get_b32_config(),
#     'ViT-L_16': get_l16_config(),
#     'ViT-L_32': get_l32_config(),
#     'ViT-H_14': get_h14_config(),
    'R50-ViT-B_16': get_r50_b16_config()
#     'R50-ViT-L_16': get_r50_l16_config(),
#     'testing': get_testing(),
}

# %%
import numpy as np
import torch
from medpy import metric
from scipy.ndimage import zoom
import torch.nn as nn
import SimpleITK as sitk


class DiceLoss(nn.Module):
    def __init__(self, n_classes):
        super(DiceLoss, self).__init__()
        self.n_classes = n_classes

    def _one_hot_encoder(self, input_tensor):
        tensor_list = []
        for i in range(self.n_classes):
            temp_prob = input_tensor == i  # * torch.ones_like(input_tensor)
            tensor_list.append(temp_prob.unsqueeze(1))
        output_tensor = torch.cat(tensor_list, dim=1)
        return output_tensor.float()

    def _dice_loss(self, score, target):
        target = target.float()
        smooth = 1e-5
        intersect = torch.sum(score * target)
        y_sum = torch.sum(target * target)
        z_sum = torch.sum(score * score)
        loss = (2 * intersect + smooth) / (z_sum + y_sum + smooth)
        loss = 1 - loss
        return loss

    def forward(self, inputs, target, weight=None, softmax=False):
        if softmax:
            inputs = torch.softmax(inputs, dim=1)
        target = self._one_hot_encoder(target)
        if weight is None:
            weight = [1] * self.n_classes
        assert inputs.size() == target.size(), 'predict {} & target {} shape do not match'.format(inputs.size(), target.size())
        class_wise_dice = []
        loss = 0.0
        for i in range(0, self.n_classes):
            dice = self._dice_loss(inputs[:, i], target[:, i])
            class_wise_dice.append(1.0 - dice.item())
            loss += dice * weight[i]
        return loss / self.n_classes


def calculate_metric_percase(pred, gt):
    pred[pred > 0] = 1
    gt[gt > 0] = 1
    if pred.sum() > 0 and gt.sum()>0:
        dice = metric.binary.dc(pred, gt)
        hd95 = metric.binary.hd95(pred, gt)
        return dice, hd95
    elif pred.sum() > 0 and gt.sum()==0:
        return 1, 0
    else:
        return 0, 0


def test_single_volume(image, label, net, classes, patch_size=[256, 256], test_save_path=None, case=None, z_spacing=1):
    image, label = image.squeeze(0).cpu().detach().numpy(), label.squeeze(0).cpu().detach().numpy()
    if len(image.shape) == 3:
        prediction = np.zeros_like(label)
        for ind in range(image.shape[0]):
            slice = image[ind, :, :]
            x, y = slice.shape[0], slice.shape[1]
            if x != patch_size[0] or y != patch_size[1]:
                slice = zoom(slice, (patch_size[0] / x, patch_size[1] / y), order=3)  # previous using 0
            input = torch.from_numpy(slice).unsqueeze(0).unsqueeze(0).float().cuda()
            net.eval()
            with torch.no_grad():
                outputs = net(input)
                out = torch.argmax(torch.softmax(outputs, dim=1), dim=1).squeeze(0)
                out = out.cpu().detach().numpy()
                if x != patch_size[0] or y != patch_size[1]:
                    pred = zoom(out, (x / patch_size[0], y / patch_size[1]), order=0)
                else:
                    pred = out
                prediction[ind] = pred
    else:
        input = torch.from_numpy(image).unsqueeze(
            0).unsqueeze(0).float().cuda()
        net.eval()
        with torch.no_grad():
            out = torch.argmax(torch.softmax(net(input), dim=1), dim=1).squeeze(0)
            prediction = out.cpu().detach().numpy()
    metric_list = []
    for i in range(1, classes):
        metric_list.append(calculate_metric_percase(prediction == i, label == i))

    if test_save_path is not None:
        img_itk = sitk.GetImageFromArray(image.astype(np.float32))
        prd_itk = sitk.GetImageFromArray(prediction.astype(np.float32))
        lab_itk = sitk.GetImageFromArray(label.astype(np.float32))
        img_itk.SetSpacing((1, 1, z_spacing))
        prd_itk.SetSpacing((1, 1, z_spacing))
        lab_itk.SetSpacing((1, 1, z_spacing))
        sitk.WriteImage(prd_itk, test_save_path + '/'+case + "_pred.nii.gz")
        sitk.WriteImage(img_itk, test_save_path + '/'+ case + "_img.nii.gz")
        sitk.WriteImage(lab_itk, test_save_path + '/'+ case + "_gt.nii.gz")
    return metric_list

# %%
import argparse
import logging
import os
import random
import sys
import time
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from tensorboardX import SummaryWriter
from torch.nn.modules.loss import CrossEntropyLoss
from torch.utils.data import DataLoader
from tqdm import tqdm
from torchvision import transforms

def worker_init_fn(worker_id):
    random.seed(1234 + worker_id)

def trainer_synapse(args, model, snapshot_path):
    logging.basicConfig(filename=snapshot_path + "/log.txt", level=logging.INFO,
                        format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
    logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
    logging.info(str(args))
    base_lr = args.base_lr
    num_classes = args.num_classes
    batch_size = args.batch_size * args.n_gpu
    # max_iterations = args.max_iterations
    db_train = Synapse_dataset(base_dir=args.root_path, list_dir=args.list_dir, split="train",
                               transform=transforms.Compose(
                                   [RandomGenerator(output_size=[args.img_size, args.img_size])]))
    print("The length of train set is: {}".format(len(db_train)))



    trainloader = DataLoader(db_train, batch_size=batch_size, shuffle=True, num_workers=8, pin_memory=True,
                             worker_init_fn=worker_init_fn)
    if args.n_gpu > 1:
        model = nn.DataParallel(model)
    model.train()
    ce_loss = CrossEntropyLoss()
    dice_loss = DiceLoss(num_classes)
    optimizer = optim.SGD(model.parameters(), lr=base_lr, momentum=0.9, weight_decay=0.0001)
    writer = SummaryWriter(snapshot_path + '/log')
    iter_num = 0
    max_epoch = args.max_epochs
    max_iterations = args.max_epochs * len(trainloader)  # max_epoch = max_iterations // len(trainloader) + 1
    logging.info("{} iterations per epoch. {} max iterations ".format(len(trainloader), max_iterations))
    best_performance = 0.0
    iterator = tqdm(range(max_epoch), ncols=70)
    for epoch_num in iterator:
        for i_batch, sampled_batch in enumerate(trainloader):
            image_batch, label_batch = sampled_batch['image'], sampled_batch['label']
            image_batch, label_batch = image_batch.cuda(), label_batch.cuda()
            outputs = model(image_batch)
            loss_ce = ce_loss(outputs, label_batch[:].long())
            loss_dice = dice_loss(outputs, label_batch, softmax=True)
            loss = 0.5 * loss_ce + 0.5 * loss_dice
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            lr_ = base_lr * (1.0 - iter_num / max_iterations) ** 0.9
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_

            iter_num = iter_num + 1
            writer.add_scalar('info/lr', lr_, iter_num)
            writer.add_scalar('info/total_loss', loss, iter_num)
            writer.add_scalar('info/loss_ce', loss_ce, iter_num)

            logging.info('iteration %d : loss : %f, loss_ce: %f' % (iter_num, loss.item(), loss_ce.item()))

            if iter_num % 20 == 0:
                image = image_batch[1, 0:1, :, :]
                image = (image - image.min()) / (image.max() - image.min())
                writer.add_image('train/Image', image, iter_num)
                outputs = torch.argmax(torch.softmax(outputs, dim=1), dim=1, keepdim=True)
                writer.add_image('train/Prediction', outputs[1, ...] * 50, iter_num)
                labs = label_batch[1, ...].unsqueeze(0) * 50
                writer.add_image('train/GroundTruth', labs, iter_num)

        save_interval = 50  # int(max_epoch/6)
        if epoch_num > int(max_epoch / 2) and (epoch_num + 1) % save_interval == 0:
            save_mode_path = os.path.join(snapshot_path, 'epoch_' + str(epoch_num) + '.pth')
            torch.save(model.state_dict(), save_mode_path)
            logging.info("save model to {}".format(save_mode_path))

        if epoch_num >= max_epoch - 1:
            save_mode_path = os.path.join(snapshot_path, 'epoch_' + str(epoch_num) + '.pth')
            torch.save(model.state_dict(), save_mode_path)
            logging.info("save model to {}".format(save_mode_path))
            iterator.close()
            break

    writer.close()
    return "Training Finished!"

# %%
import argparse
import logging
import os
import random
import numpy as np
import torch
import torch.backends.cudnn as cudnn
import argparse

import torch
torch.cuda.empty_cache()


parser = argparse.ArgumentParser()
parser.add_argument('--root_path', type=str,
                    default='/content/gdrive/MyDrive/Synapse/train_npz', help='root dir for data')
parser.add_argument('--dataset', type=str,
                    default='Synapse', help='experiment_name')
parser.add_argument('--list_dir', type=str,
                    default='/content/gdrive/MyDrive/Synapse/TransUNet-main/lists/lists_Synapse', help='list dir')
parser.add_argument('--num_classes', type=int,
                    default=9, help='output channel of network')
parser.add_argument('--max_iterations', type=int,
                    default=30000, help='maximum epoch number to train')
parser.add_argument('--max_epochs', type=int,
                    default=150, help='maximum epoch number to train')
parser.add_argument('--batch_size', type=int,
                    default=8, help='batch_size per gpu')
parser.add_argument('--n_gpu', type=int, default=1, help='total gpu')
parser.add_argument('--deterministic', type=int,  default=1,
                    help='whether use deterministic training')
parser.add_argument('--base_lr', type=float,  default=0.01,
                    help='segmentation network learning rate')
parser.add_argument('--img_size', type=int,
                    default=224, help='input patch size of network input')
parser.add_argument('--seed', type=int,
                    default=1234, help='random seed')
parser.add_argument('--n_skip', type=int,
                    default=3, help='using number of skip-connect, default is num')
parser.add_argument('--vit_name', type=str,
                    default='R50-ViT-B_16', help='select one vit model')
parser.add_argument('--vit_patches_size', type=int,
                    default=16, help='vit_patches_size, default is 16')
parser.add_argument('-f')
args = parser.parse_args()


if __name__ == "__main__":
    if not args.deterministic:
        cudnn.benchmark = True
        cudnn.deterministic = False
    else:
        cudnn.benchmark = False
        cudnn.deterministic = True

    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed(args.seed)
    dataset_name = args.dataset
    dataset_config = {
        'Synapse': {
            'root_path': '/content/gdrive/MyDrive/Synapse/train_npz',
            'list_dir': '/content/gdrive/MyDrive/Synapse/TransUNet-main/lists/lists_Synapse',
            'num_classes': 9,
        },
    }
    args.num_classes = dataset_config[dataset_name]['num_classes']
    args.root_path = dataset_config[dataset_name]['root_path']
    args.list_dir = dataset_config[dataset_name]['list_dir']
    args.is_pretrain = True
    args.exp = 'TU_' + dataset_name + str(args.img_size)
    snapshot_path = "/content/vit new/model/".format(args.exp, 'TU')
    snapshot_path = snapshot_path + '_pretrain' if args.is_pretrain else snapshot_path
    snapshot_path += '_' + args.vit_name
    snapshot_path = snapshot_path + '_skip' + str(args.n_skip)
    snapshot_path = snapshot_path + '_vitpatch' + str(args.vit_patches_size) if args.vit_patches_size!=16 else snapshot_path
    snapshot_path = snapshot_path+'_'+str(args.max_iterations)[0:2]+'k' if args.max_iterations != 30000 else snapshot_path
    snapshot_path = snapshot_path + '_epo' +str(args.max_epochs) if args.max_epochs != 30 else snapshot_path
    snapshot_path = snapshot_path+'_bs'+str(args.batch_size)
    snapshot_path = snapshot_path + '_lr' + str(args.base_lr) if args.base_lr != 0.01 else snapshot_path
    snapshot_path = snapshot_path + '_'+str(args.img_size)
    snapshot_path = snapshot_path + '_s'+str(args.seed) if args.seed!=1234 else snapshot_path

    if not os.path.exists(snapshot_path):
        os.makedirs(snapshot_path)
    config_vit=CONFIGS[args.vit_name]
    config_vit.n_classes = args.num_classes
    config_vit.n_skip = args.n_skip
    if args.vit_name.find('R50') != -1:
        config_vit.patches.grid = (int(args.img_size / args.vit_patches_size), int(args.img_size / args.vit_patches_size))
    net = VisionTransformer(config_vit, img_size=args.img_size, num_classes=config_vit.n_classes).cuda()
    net.load_from(weights=np.load(config_vit.pretrained_path))

    trainer = {'Synapse': trainer_synapse,}
    trainer[dataset_name](args, net, snapshot_path)

    # net(torch.zeros((1,3,224,224)))
# Out:
# load_pretrained: grid-size from 24 to 14
# Namespace(base_lr=0.01, batch_size=8, dataset='Synapse', deterministic=1, exp='TU_Synapse224', f='/root/.local/share/jupyter/runtime/kernel-103918b3-b150-41c2-8bd9-2382add004ff.json', img_size=224, is_pretrain=True, list_dir='/content/gdrive/MyDrive/Synapse/TransUNet-main/lists/lists_Synapse', max_epochs=150, max_iterations=30000, n_gpu=1, n_skip=3, num_classes=9, root_path='/content/gdrive/MyDrive/Synapse/train_npz', seed=1234, vit_name='R50-ViT-B_16', vit_patches_size=16)
# The length of train set is: 2211
# 277 iterations per epoch. 41550 max iterations
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|                                         | 0/150 [00:00<?, ?it/s]
# iteration 1 : loss : 1.532318, loss_ce: 2.141530
# iteration 2 : loss : 1.528255, loss_ce: 2.132218
# iteration 3 : loss : 1.540132, loss_ce: 2.108438
# iteration 4 : loss : 1.509062, loss_ce: 2.091883
# iteration 5 : loss : 1.500453, loss_ce: 2.053112
# iteration 6 : loss : 1.474040, loss_ce: 2.021042
# iteration 7 : loss : 1.448971, loss_ce: 1.988415
# iteration 8 : loss : 1.426161, loss_ce: 1.943095
# iteration 9 : loss : 1.407766, loss_ce: 1.889406
# iteration 10 : loss : 1.379988, loss_ce: 1.844331
# iteration 11 : loss : 1.354470, loss_ce: 1.789371
# iteration 12 : loss : 1.321379, loss_ce: 1.729595
# iteration 13 : loss : 1.291789, loss_ce: 1.685439
# iteration 14 : loss : 1.252116, loss_ce: 1.595566
# iteration 15 : loss : 1.229019, loss_ce: 1.550245
# iteration 16 : loss : 1.184063, loss_ce: 1.468101
# iteration 17 : loss : 1.142364, loss_ce: 1.379033
# iteration 18 : loss : 1.107218, loss_ce: 1.304363
# iteration 19 : loss : 1.071951, loss_ce: 1.233333
# iteration 20 : loss : 1.033754, loss_ce: 1.146507
# iteration 21 : loss : 1.009101, loss_ce: 1.151302
# iteration 22 : loss : 0.957669, loss_ce: 1.039382
# iteration 23 : loss : 0.916185, loss_ce: 0.946630
# iteration 24 : loss : 0.888673, loss_ce: 0.874950
# iteration 25 : loss : 0.868604, loss_ce: 0.883389
# iteration 26 : loss : 0.827274, loss_ce: 0.784557
# iteration 27 : loss : 0.812845, loss_ce: 0.772211
# iteration 28 : loss : 0.778108, loss_ce: 0.703705
# iteration 29 : loss : 0.760892, loss_ce: 0.666514
# iteration 30 : loss : 0.761219, loss_ce: 0.666965
# iteration 31 : loss : 0.729192, loss_ce: 0.622070
# iteration 32 : loss : 0.707401, loss_ce: 0.573664
# iteration 33 : loss : 0.659000, loss_ce: 0.436429
# iteration 34 : loss : 0.664919, loss_ce: 0.481898
# iteration 35 : loss : 0.678360, loss_ce: 0.521331
# iteration 36 : loss : 0.620917, loss_ce: 0.362874
# iteration 37 : loss : 0.627431, loss_ce: 0.411018
# iteration 38 : loss : 0.613142, loss_ce: 0.369376
# iteration 39 : loss : 0.637715, loss_ce: 0.426573
# iteration 40 : loss : 0.596689, loss_ce: 0.349635
# iteration 41 : loss : 0.632920, loss_ce: 0.424505
# iteration 42 : loss : 0.570604, loss_ce: 0.291159
# iteration 43 : loss : 0.627314, loss_ce: 0.408603
# iteration 44 : loss : 0.556668, loss_ce: 0.265717
# iteration 45 : loss : 0.608508, loss_ce: 0.367048
# iteration 46 : loss : 0.553771, loss_ce: 0.252663
# iteration 47 : loss : 0.575536, loss_ce: 0.290669
# iteration 48 : loss : 0.578302, loss_ce: 0.304944
# iteration 49 : loss : 0.523080, loss_ce: 0.190253
# iteration 50 : loss : 0.576762, loss_ce: 0.304224
# iteration 51 : loss : 0.529510, loss_ce: 0.203442
# iteration 52 : loss : 0.529195, loss_ce: 0.208064
# iteration 53 : loss : 0.570402, loss_ce: 0.296481
# iteration 54 : loss : 0.539006, loss_ce: 0.217502
# iteration 55 : loss : 0.579516, loss_ce: 0.315122
# iteration 56 : loss : 0.579754, loss_ce: 0.318614
# iteration 57 : loss : 0.555041, loss_ce: 0.257856
# iteration 58 : loss : 0.544660, loss_ce: 0.245815
# iteration 59 : loss : 0.529022, loss_ce: 0.198308
# iteration 60 : loss : 0.564059, loss_ce: 0.264988
# iteration 61 : loss : 0.524486, loss_ce: 0.191624
# iteration 62 : loss : 0.531845, loss_ce: 0.220970
# iteration 63 : loss : 0.604807, loss_ce: 0.371169
# iteration 64 : loss : 0.553324, loss_ce: 0.267127
# iteration 65 : loss : 0.558701, loss_ce: 0.274356
# iteration 66 : loss : 0.543970, loss_ce: 0.247730
# iteration 67 : loss : 0.565938, loss_ce: 0.296605
# iteration 68 : loss : 0.563289, loss_ce: 0.285028
# iteration 69 : loss : 0.556323, loss_ce: 0.278578
# iteration 70 : loss : 0.521618, loss_ce: 0.201496
# iteration 71 : loss : 0.501190, loss_ce: 0.138393
# iteration 72 : loss : 0.543304, loss_ce: 0.252512
# iteration 73 : loss : 0.508921, loss_ce: 0.169032
# iteration 74 : loss : 0.508610, loss_ce: 0.158103
# iteration 75 : loss : 0.519749, loss_ce: 0.197416
# iteration 76 : loss : 0.505465, loss_ce: 0.178499
# iteration 77 : loss : 0.525432, loss_ce: 0.209775
# iteration 78 : loss : 0.561504, loss_ce: 0.281986
# iteration 79 : loss : 0.508557, loss_ce: 0.177989
# iteration 80 : loss : 0.524656, loss_ce: 0.214698
# iteration 81 : loss : 0.517927, loss_ce: 0.199540
# iteration 82 : loss : 0.497002, loss_ce: 0.137108
# iteration 83 : loss : 0.495995, loss_ce: 0.155223
# iteration 84 : loss : 0.522835, loss_ce: 0.219477
# iteration 85 : loss : 0.520613, loss_ce: 0.209580
# iteration 86 : loss : 0.559027, loss_ce: 0.258705
# iteration 87 : loss : 0.508837, loss_ce: 0.184677
# iteration 88 : loss : 0.485030, loss_ce: 0.108661
# iteration 89 : loss : 0.540748, loss_ce: 0.240251
# iteration 90 : loss : 0.527787, loss_ce: 0.223553
# iteration 91 : loss : 0.537536, loss_ce: 0.243901
# iteration 92 : loss : 0.536714, loss_ce: 0.229502
# iteration 93 : loss : 0.485042, loss_ce: 0.124291
# iteration 94 : loss : 0.535935, loss_ce: 0.242567
# iteration 95 : loss : 0.553447, loss_ce: 0.281282
# iteration 96 : loss : 0.576741, loss_ce: 0.331509
# iteration 97 : loss : 0.533610, loss_ce: 0.228130
# iteration 98 : loss : 0.539084, loss_ce: 0.250200
# iteration 99 : loss : 0.584059, loss_ce: 0.324402
# iteration 100 : loss : 0.538124, loss_ce: 0.236882
# iteration 101 : loss : 0.510462, loss_ce: 0.192365
# iteration 102 : loss : 0.537002, loss_ce: 0.253575
# iteration 103 : loss : 0.524276, loss_ce: 0.226020
# iteration 104 : loss : 0.524213, loss_ce: 0.227159
# iteration 105 : loss : 0.563017, loss_ce: 0.301059
# iteration 106 : loss : 0.514862, loss_ce: 0.202184
# iteration 107 : loss : 0.502337, loss_ce: 0.185165
# iteration 108 : loss : 0.574918, loss_ce: 0.328624
# iteration 109 : loss : 0.496942, loss_ce: 0.181589
# iteration 110 : loss : 0.541658, loss_ce: 0.265760
# iteration 111 : loss : 0.541328, loss_ce: 0.264116
# iteration 112 : loss : 0.551378, loss_ce: 0.283541
# iteration 113 : loss : 0.571952, loss_ce: 0.303476
# iteration 114 : loss : 0.500927, loss_ce: 0.176626
# iteration 115 : loss : 0.542421, loss_ce: 0.266916
# iteration 116 : loss : 0.502446, loss_ce: 0.180469
# iteration 117 : loss : 0.532808, loss_ce: 0.236251
# iteration 118 : loss : 0.547493, loss_ce: 0.278971
# iteration 119 : loss : 0.505619, loss_ce: 0.189833
# iteration 120 : loss : 0.533674, loss_ce: 0.244499
# iteration 121 : loss : 0.491135, loss_ce: 0.149738
# iteration 122 : loss : 0.537436, loss_ce: 0.257930
# iteration 123 : loss : 0.501995, loss_ce: 0.159179
# iteration 124 : loss : 0.496603, loss_ce: 0.187134
# iteration 125 : loss : 0.495920, loss_ce: 0.178605
# iteration 126 : loss : 0.482216, loss_ce: 0.094639
# iteration 127 : loss : 0.498636, loss_ce: 0.165348
# iteration 128 : loss : 0.504598, loss_ce: 0.189670
# iteration 129 : loss : 0.509808, loss_ce: 0.178590
# iteration 130 : loss : 0.557590, loss_ce: 0.290311
# iteration 131 : loss : 0.497271, loss_ce: 0.161483
# iteration 132 : loss : 0.518830, loss_ce: 0.209757
# iteration 133 : loss : 0.507055, loss_ce: 0.192501
# iteration 134 : loss : 0.543948, loss_ce: 0.239801
# iteration 135 : loss : 0.535957, loss_ce: 0.247557
# iteration 136 : loss : 0.504784, loss_ce: 0.199823
# iteration 137 : loss : 0.489810, loss_ce: 0.147056
# iteration 138 : loss : 0.484163, loss_ce: 0.127721
# iteration 139 : loss : 0.487407, loss_ce: 0.159614
# iteration 140 : loss : 0.542550, loss_ce: 0.266010
# iteration 141 : loss : 0.511238, loss_ce: 0.205764
# iteration 142 : loss : 0.503978, loss_ce: 0.188325
# iteration 143 : loss : 0.485106, loss_ce: 0.103914
# iteration 144 : loss : 0.551407, loss_ce: 0.259832
# iteration 145 : loss : 0.533800, loss_ce: 0.258819
# iteration 146 : loss : 0.533469, loss_ce: 0.243306
# iteration 147 : loss : 0.520803, loss_ce: 0.225767
# iteration 148 : loss : 0.487535, loss_ce: 0.090725
# iteration 149 : loss : 0.478734, loss_ce: 0.148776
# iteration 150 : loss : 0.543823, loss_ce: 0.264275
# iteration 151 : loss : 0.526714, loss_ce: 0.227639
# iteration 152 : loss : 0.504683, loss_ce: 0.185406
# iteration 153 : loss : 0.516988, loss_ce: 0.220890
# iteration 154 : loss : 0.514804, loss_ce: 0.194999
# iteration 155 : loss : 0.533819, loss_ce: 0.254077
# iteration 156 : loss : 0.500621, loss_ce: 0.173945
# iteration 157 : loss : 0.517807, loss_ce: 0.209396
# iteration 158 : loss : 0.546602, loss_ce: 0.267858
# iteration 159 : loss : 0.533470, loss_ce: 0.240490
# iteration 160 : loss : 0.491942, loss_ce: 0.154111
# iteration 161 : loss : 0.555748, loss_ce: 0.289958
# iteration 162 : loss : 0.488343, loss_ce: 0.156434
# iteration 163 : loss : 0.573251, loss_ce: 0.319828
# iteration 164 : loss : 0.495244, loss_ce: 0.166357
# iteration 165 : loss : 0.485827, loss_ce: 0.092043
# iteration 166 : loss : 0.499598, loss_ce: 0.178724
# iteration 167 : loss : 0.551349, loss_ce: 0.297351
# iteration 168 : loss : 0.499840, loss_ce: 0.203709
# iteration 169 : loss : 0.578182, loss_ce: 0.325902
# iteration 170 : loss : 0.478329, loss_ce: 0.143210
# iteration 171 : loss : 0.472948, loss_ce: 0.108879
# iteration 172 : loss : 0.507270, loss_ce: 0.208783
# iteration 173 : loss : 0.493413, loss_ce: 0.176703
# iteration 174 : loss : 0.543207, loss_ce: 0.271787
# iteration 175 : loss : 0.488263, loss_ce: 0.147834
# iteration 176 : loss : 0.533816, loss_ce: 0.248560
# iteration 177 : loss : 0.505925, loss_ce: 0.182425
# iteration 178 : loss : 0.497755, loss_ce: 0.168934
# iteration 179 : loss : 0.489509, loss_ce: 0.159014
# iteration 180 : loss : 0.501885, loss_ce: 0.186248
# iteration 181 : loss : 0.494630, loss_ce: 0.169002
# iteration 182 : loss : 0.517920, loss_ce: 0.212326
# iteration 183 : loss : 0.570540, loss_ce: 0.326425
# iteration 184 : loss : 0.532454, loss_ce: 0.251271
# iteration 185 : loss : 0.508284, loss_ce: 0.207363
# iteration 186 : loss : 0.537109, loss_ce: 0.262698
# iteration 187 : loss : 0.514328, loss_ce: 0.192871
# iteration 188 : loss : 0.495501, loss_ce: 0.153290
# iteration 189 : loss : 0.523048, loss_ce: 0.224046
# iteration 190 : loss : 0.470769, loss_ce: 0.127548
# iteration 191 : loss : 0.480943, loss_ce: 0.129657
# iteration 192 : loss : 0.517541, loss_ce: 0.215831
# iteration 193 : loss : 0.515959, loss_ce: 0.225916
# iteration 194 : loss : 0.508244, loss_ce: 0.211140
# iteration 195 : loss : 0.513050, loss_ce: 0.188435
# iteration 196 : loss : 0.507591, loss_ce: 0.199873
# iteration 197 : loss : 0.540542, loss_ce: 0.265169
# iteration 198 : loss : 0.480449, loss_ce: 0.096170
# iteration 199 : loss : 0.477621, loss_ce: 0.140438
# iteration 200 : loss : 0.513754, loss_ce: 0.222993
# iteration 201 : loss : 0.493012, loss_ce: 0.166500
# iteration 202 : loss : 0.553114, loss_ce: 0.289075
# iteration 203 : loss : 0.491921, loss_ce: 0.155125
# iteration 204 : loss : 0.474097, loss_ce: 0.144766
# iteration 205 : loss : 0.525633, loss_ce: 0.226257
# iteration 206 : loss : 0.506406, loss_ce: 0.200196
# iteration 207 : loss : 0.482375, loss_ce: 0.133537
# iteration 208 : loss : 0.515925, loss_ce: 0.215366
# iteration 209 : loss : 0.563040, loss_ce: 0.307034
# iteration 210 : loss : 0.494603, loss_ce: 0.169278
# iteration 211 : loss : 0.503309, loss_ce: 0.179786
# iteration 212 : loss : 0.495744, loss_ce: 0.149531
# iteration 213 : loss : 0.473555, loss_ce: 0.120457
# iteration 214 : loss : 0.486032, loss_ce: 0.132482
# iteration 215 : loss : 0.498523, loss_ce: 0.183823
# iteration 216 : loss : 0.481557, loss_ce: 0.154530
# iteration 217 : loss : 0.496843, loss_ce: 0.173842
# iteration 218 : loss : 0.483220, loss_ce: 0.142374
# iteration 219 : loss : 0.469442, loss_ce: 0.119006
# iteration 220 : loss : 0.463192, loss_ce: 0.081916
# iteration 221 : loss : 0.492943, loss_ce: 0.180976
# iteration 222 : loss : 0.475547, loss_ce: 0.114777
# iteration 223 : loss : 0.460595, loss_ce: 0.076662
# iteration 224 : loss : 0.478616, loss_ce: 0.138922
# iteration 225 : loss : 0.474563, loss_ce: 0.136826
# iteration 226 : loss : 0.516400, loss_ce: 0.213799
# iteration 227 : loss : 0.512288, loss_ce: 0.205485
# iteration 228 : loss : 0.534364, loss_ce: 0.251750
# iteration 229 : loss : 0.538993, loss_ce: 0.263643
# iteration 230 : loss : 0.489734, loss_ce: 0.176156
# iteration 231 : loss : 0.471116, loss_ce: 0.105354
# iteration 232 : loss : 0.489116, loss_ce: 0.174633
# iteration 233 : loss : 0.470030, loss_ce: 0.113733
# iteration 234 : loss : 0.485816, loss_ce: 0.172113
# iteration 235 : loss : 0.479056, loss_ce: 0.115352
# iteration 236 : loss : 0.534773, loss_ce: 0.250344
# iteration 237 : loss : 0.501289, loss_ce: 0.191616
# iteration 238 : loss : 0.511675, loss_ce: 0.195751
# iteration 239 : loss : 0.539263, loss_ce: 0.266548
# iteration 240 : loss : 0.476717, loss_ce: 0.089751
# iteration 241 : loss : 0.470877, loss_ce: 0.138471
# iteration 242 : loss : 0.502066, loss_ce: 0.171979
# iteration 243 : loss : 0.504305, loss_ce: 0.182173
# iteration 244 : loss : 0.551751, loss_ce: 0.283739
# iteration 245 : loss : 0.499073, loss_ce: 0.177781
# iteration 246 : loss : 0.495504, loss_ce: 0.180846
# iteration 247 : loss : 0.507554, loss_ce: 0.206619
# iteration 248 : loss : 0.470791, loss_ce: 0.124689
# iteration 249 : loss : 0.470630, loss_ce: 0.127719
# iteration 250 : loss : 0.474850, loss_ce: 0.135402
# iteration 251 : loss : 0.498413, loss_ce: 0.178049
# iteration 252 : loss : 0.502309, loss_ce: 0.206756
# iteration 253 : loss : 0.464111, loss_ce: 0.091499
# iteration 254 : loss : 0.582540, loss_ce: 0.346391
# iteration 255 : loss : 0.483254, loss_ce: 0.130662
# iteration 256 : loss : 0.486468, loss_ce: 0.168370
# iteration 257 : loss : 0.487205, loss_ce: 0.170791
# iteration 258 : loss : 0.522106, loss_ce: 0.223764
# iteration 259 : loss : 0.482213, loss_ce: 0.128734
# iteration 260 : loss : 0.489094, loss_ce: 0.175600
# iteration 261 : loss : 0.496526, loss_ce: 0.151015
# iteration 262 : loss : 0.463042, loss_ce: 0.132240
# iteration 263 : loss : 0.476244, loss_ce: 0.104821
# iteration 264 : loss : 0.488393, loss_ce: 0.153455
# iteration 265 : loss : 0.478405, loss_ce: 0.145419
# iteration 266 : loss : 0.465953, loss_ce: 0.112532
# iteration 267 : loss : 0.469669, loss_ce: 0.079788
# iteration 268 : loss : 0.492869, loss_ce: 0.170428
# iteration 269 : loss : 0.466466, loss_ce: 0.139381
# iteration 270 : loss : 0.494017, loss_ce: 0.174677
# iteration 271 : loss : 0.460725, loss_ce: 0.088663
# iteration 272 : loss : 0.530204, loss_ce: 0.247031
# iteration 273 : loss : 0.504738, loss_ce: 0.193135
# iteration 274 : loss : 0.493697, loss_ce: 0.182658
# iteration 275 : loss : 0.515524, loss_ce: 0.200166
# iteration 276 : loss : 0.486733, loss_ce: 0.168913
# iteration 277 : loss : 0.620233, loss_ce: 0.404417
#   1%|▏                             | 1/150 [03:59<9:55:28, 239.79s/it]
# iteration 278 : loss : 0.483133, loss_ce: 0.157916
# iteration 279 : loss : 0.471143, loss_ce: 0.104228
# iteration 280 : loss : 0.503016, loss_ce: 0.192359
# iteration 281 : loss : 0.519991, loss_ce: 0.207117
# iteration 282 : loss : 0.510369, loss_ce: 0.200379
# iteration 283 : loss : 0.493725, loss_ce: 0.170882
# iteration 284 : loss : 0.578140, loss_ce: 0.346245
# iteration 285 : loss : 0.474598, loss_ce: 0.120394
# iteration 286 : loss : 0.522615, loss_ce: 0.211147
# iteration 287 : loss : 0.477952, loss_ce: 0.094608
# iteration 288 : loss : 0.459610, loss_ce: 0.097883
# iteration 289 : loss : 0.471832, loss_ce: 0.112716
# iteration 290 : loss : 0.501979, loss_ce: 0.197606
# iteration 291 : loss : 0.469497, loss_ce: 0.109336
# iteration 292 : loss : 0.471608, loss_ce: 0.081003
# iteration 293 : loss : 0.492294, loss_ce: 0.187600
# iteration 294 : loss : 0.556315, loss_ce: 0.294293
# iteration 295 : loss : 0.486978, loss_ce: 0.172888
# iteration 296 : loss : 0.471454, loss_ce: 0.139170
# iteration 297 : loss : 0.496138, loss_ce: 0.178790
# iteration 298 : loss : 0.473751, loss_ce: 0.136153
# iteration 299 : loss : 0.507556, loss_ce: 0.173425
# iteration 300 : loss : 0.464710, loss_ce: 0.134351
# iteration 301 : loss : 0.502073, loss_ce: 0.191195
# iteration 302 : loss : 0.467228, loss_ce: 0.120596
# iteration 303 : loss : 0.502298, loss_ce: 0.183818
# iteration 304 : loss : 0.463806, loss_ce: 0.103916
# iteration 305 : loss : 0.559764, loss_ce: 0.302273
# iteration 306 : loss : 0.462753, loss_ce: 0.122640
# iteration 307 : loss : 0.455889, loss_ce: 0.116852
# iteration 308 : loss : 0.482626, loss_ce: 0.164251
# iteration 309 : loss : 0.461862, loss_ce: 0.065875
# iteration 310 : loss : 0.480570, loss_ce: 0.153280
# iteration 311 : loss : 0.475918, loss_ce: 0.125816
# iteration 312 : loss : 0.486845, loss_ce: 0.164828
# iteration 313 : loss : 0.475466, loss_ce: 0.150829
# iteration 314 : loss : 0.452901, loss_ce: 0.105873
# iteration 315 : loss : 0.478702, loss_ce: 0.141122
# iteration 316 : loss : 0.478252, loss_ce: 0.151641
# iteration 317 : loss : 0.499108, loss_ce: 0.176090
# iteration 318 : loss : 0.480870, loss_ce: 0.139498
# iteration 319 : loss : 0.491129, loss_ce: 0.163312
# iteration 320 : loss : 0.464288, loss_ce: 0.129315
# iteration 321 : loss : 0.471028, loss_ce: 0.127131
# iteration 322 : loss : 0.468504, loss_ce: 0.114014
# iteration 323 : loss : 0.471871, loss_ce: 0.112503
# iteration 324 : loss : 0.453535, loss_ce: 0.099240
# iteration 325 : loss : 0.446509, loss_ce: 0.094091
# iteration 326 : loss : 0.462008, loss_ce: 0.068532
# iteration 327 : loss : 0.470022, loss_ce: 0.143044
# iteration 328 : loss : 0.480010, loss_ce: 0.157527
# iteration 329 : loss : 0.472875, loss_ce: 0.149772
# iteration 330 : loss : 0.467849, loss_ce: 0.121635
# iteration 331 : loss : 0.494370, loss_ce: 0.184942
# iteration 332 : loss : 0.457967, loss_ce: 0.111149
# iteration 333 : loss : 0.490387, loss_ce: 0.176310
# iteration 334 : loss : 0.477014, loss_ce: 0.129792
# iteration 335 : loss : 0.513042, loss_ce: 0.210267
# iteration 336 : loss : 0.539804, loss_ce: 0.255180
# iteration 337 : loss : 0.473549, loss_ce: 0.145598
# iteration 338 : loss : 0.482175, loss_ce: 0.164983
# iteration 339 : loss : 0.457970, loss_ce: 0.075840
# iteration 340 : loss : 0.463252, loss_ce: 0.129566
# iteration 341 : loss : 0.509425, loss_ce: 0.210072
# iteration 342 : loss : 0.465916, loss_ce: 0.117007
# iteration 343 : loss : 0.468367, loss_ce: 0.126695
# iteration 344 : loss : 0.495932, loss_ce: 0.183559
# iteration 345 : loss : 0.458708, loss_ce: 0.117614
# iteration 346 : loss : 0.503862, loss_ce: 0.177598
# iteration 347 : loss : 0.472812, loss_ce: 0.131986
# iteration 348 : loss : 0.498227, loss_ce: 0.200622
# iteration 349 : loss : 0.463749, loss_ce: 0.141339
# iteration 350 : loss : 0.526339, loss_ce: 0.243750
# iteration 351 : loss : 0.506935, loss_ce: 0.185169
# iteration 352 : loss : 0.502079, loss_ce: 0.209298
# iteration 353 : loss : 0.482634, loss_ce: 0.174868
# iteration 354 : loss : 0.483518, loss_ce: 0.174311
# iteration 355 : loss : 0.464445, loss_ce: 0.094630
# iteration 356 : loss : 0.503738, loss_ce: 0.183440
# iteration 357 : loss : 0.496739, loss_ce: 0.204791
# iteration 358 : loss : 0.525555, loss_ce: 0.252466
# iteration 359 : loss : 0.458454, loss_ce: 0.111550
# iteration 360 : loss : 0.484524, loss_ce: 0.164395
# iteration 361 : loss : 0.514818, loss_ce: 0.217868
# iteration 362 : loss : 0.487313, loss_ce: 0.177176
# iteration 363 : loss : 0.504328, loss_ce: 0.211938
# iteration 364 : loss : 0.451175, loss_ce: 0.106628
# iteration 365 : loss : 0.496579, loss_ce: 0.195311
# iteration 366 : loss : 0.495108, loss_ce: 0.199088
# iteration 367 : loss : 0.472501, loss_ce: 0.138772
# iteration 368 : loss : 0.485558, loss_ce: 0.144982
# iteration 369 : loss : 0.495402, loss_ce: 0.196694
# iteration 370 : loss : 0.498856, loss_ce: 0.195641
# iteration 371 : loss : 0.490622, loss_ce: 0.174044
# iteration 372 : loss : 0.493812, loss_ce: 0.205708
# iteration 373 : loss : 0.484961, loss_ce: 0.168698
# iteration 374 : loss : 0.470959, loss_ce: 0.148464
# iteration 375 : loss : 0.466505, loss_ce: 0.136117
# iteration 376 : loss : 0.519917, loss_ce: 0.239588
# iteration 377 : loss : 0.476356, loss_ce: 0.153781
# iteration 378 : loss : 0.470102, loss_ce: 0.151569
# iteration 379 : loss : 0.493863, loss_ce: 0.195408
# iteration 380 : loss : 0.497821, loss_ce: 0.210590
# iteration 381 : loss : 0.461246, loss_ce: 0.106230
# iteration 382 : loss : 0.440501, loss_ce: 0.102201
# iteration 383 : loss : 0.534684, loss_ce: 0.274720
# iteration 384 : loss : 0.477179, loss_ce: 0.162581
# iteration 385 : loss : 0.482363, loss_ce: 0.174267
# iteration 386 : loss : 0.464699, loss_ce: 0.145646
# iteration 387 : loss : 0.465079, loss_ce: 0.145119
# iteration 388 : loss : 0.489813, loss_ce: 0.173149
# iteration 389 : loss : 0.463063, loss_ce: 0.104002
# iteration 390 : loss : 0.451099, loss_ce: 0.089393
# iteration 391 : loss : 0.465906, loss_ce: 0.109782
# iteration 392 : loss : 0.513071, loss_ce: 0.232938
# iteration 393 : loss : 0.453012, loss_ce: 0.099511
# iteration 394 : loss : 0.472782, loss_ce: 0.152923
# iteration 395 : loss : 0.450672, loss_ce: 0.103109
# iteration 396 : loss : 0.513920, loss_ce: 0.220337
# iteration 397 : loss : 0.494457, loss_ce: 0.191219
# iteration 398 : loss : 0.500859, loss_ce: 0.185165
# iteration 399 : loss : 0.462091, loss_ce: 0.085083
# iteration 400 : loss : 0.470037, loss_ce: 0.089431
# iteration 401 : loss : 0.576565, loss_ce: 0.336373
# iteration 402 : loss : 0.566592, loss_ce: 0.326924
# iteration 403 : loss : 0.486919, loss_ce: 0.178850
# iteration 404 : loss : 0.476432, loss_ce: 0.174243
# iteration 405 : loss : 0.454683, loss_ce: 0.125370
# iteration 406 : loss : 0.470410, loss_ce: 0.158750
# iteration 407 : loss : 0.487005, loss_ce: 0.196163
# iteration 408 : loss : 0.461723, loss_ce: 0.136280
# iteration 409 : loss : 0.456768, loss_ce: 0.130501
# iteration 410 : loss : 0.472011, loss_ce: 0.170579
# iteration 411 : loss : 0.451841, loss_ce: 0.113061
# iteration 412 : loss : 0.457163, loss_ce: 0.141397
# iteration 413 : loss : 0.452937, loss_ce: 0.127979
# iteration 414 : loss : 0.479255, loss_ce: 0.166567
# iteration 415 : loss : 0.466600, loss_ce: 0.166623
# iteration 416 : loss : 0.454223, loss_ce: 0.124011
# iteration 417 : loss : 0.448391, loss_ce: 0.126732
# iteration 418 : loss : 0.449756, loss_ce: 0.115300
# iteration 419 : loss : 0.446407, loss_ce: 0.106722
# iteration 420 : loss : 0.466994, loss_ce: 0.159520
# iteration 421 : loss : 0.442651, loss_ce: 0.114998
# iteration 422 : loss : 0.462534, loss_ce: 0.116930
# iteration 423 : loss : 0.459000, loss_ce: 0.145805
# iteration 424 : loss : 0.456890, loss_ce: 0.129286
# iteration 425 : loss : 0.483394, loss_ce: 0.160019
# iteration 426 : loss : 0.466014, loss_ce: 0.150236
# iteration 427 : loss : 0.433757, loss_ce: 0.085584
# iteration 428 : loss : 0.467247, loss_ce: 0.151463
# iteration 429 : loss : 0.567311, loss_ce: 0.313213
# iteration 430 : loss : 0.459446, loss_ce: 0.145587
# iteration 431 : loss : 0.453198, loss_ce: 0.136792
# iteration 432 : loss : 0.470063, loss_ce: 0.116574
# iteration 433 : loss : 0.520439, loss_ce: 0.246258
# iteration 434 : loss : 0.508038, loss_ce: 0.226366
# iteration 435 : loss : 0.515835, loss_ce: 0.214800
# iteration 436 : loss : 0.450616, loss_ce: 0.122365
# iteration 437 : loss : 0.457855, loss_ce: 0.103942
# iteration 438 : loss : 0.502837, loss_ce: 0.219361
# iteration 439 : loss : 0.476091, loss_ce: 0.169194
# iteration 440 : loss : 0.501538, loss_ce: 0.225914
# iteration 441 : loss : 0.453376, loss_ce: 0.146446
# iteration 442 : loss : 0.474433, loss_ce: 0.179517
# iteration 443 : loss : 0.474160, loss_ce: 0.169140
# iteration 444 : loss : 0.450254, loss_ce: 0.136366
# iteration 445 : loss : 0.458911, loss_ce: 0.100878
# iteration 446 : loss : 0.453947, loss_ce: 0.102015
# iteration 447 : loss : 0.465596, loss_ce: 0.156380
# iteration 448 : loss : 0.454853, loss_ce: 0.124721
# iteration 449 : loss : 0.455068, loss_ce: 0.131002
# iteration 450 : loss : 0.549861, loss_ce: 0.298413
# iteration 451 : loss : 0.492166, loss_ce: 0.190826
# iteration 452 : loss : 0.472051, loss_ce: 0.176652
# iteration 453 : loss : 0.461315, loss_ce: 0.156659
# iteration 454 : loss : 0.473996, loss_ce: 0.174583
# iteration 455 : loss : 0.470975, loss_ce: 0.147496
# iteration 456 : loss : 0.451522, loss_ce: 0.131874
# iteration 457 : loss : 0.466954, loss_ce: 0.158314
# iteration 458 : loss : 0.465889, loss_ce: 0.156917
# iteration 459 : loss : 0.478271, loss_ce: 0.189814
# iteration 460 : loss : 0.473609, loss_ce: 0.096119
# iteration 461 : loss : 0.443495, loss_ce: 0.131639
# iteration 462 : loss : 0.443307, loss_ce: 0.121935
# iteration 463 : loss : 0.468671, loss_ce: 0.126266
# iteration 464 : loss : 0.466394, loss_ce: 0.160792
# iteration 465 : loss : 0.440241, loss_ce: 0.105123
# iteration 466 : loss : 0.438720, loss_ce: 0.120432
# iteration 467 : loss : 0.434193, loss_ce: 0.104511
# iteration 468 : loss : 0.440723, loss_ce: 0.111063
# iteration 469 : loss : 0.457589, loss_ce: 0.141255
# iteration 470 : loss : 0.466212, loss_ce: 0.159876
# iteration 471 : loss : 0.488209, loss_ce: 0.197508
# iteration 472 : loss : 0.479156, loss_ce: 0.170422
# iteration 473 : loss : 0.448263, loss_ce: 0.117147
# iteration 474 : loss : 0.489227, loss_ce: 0.189657
# iteration 475 : loss : 0.459390, loss_ce: 0.141316
# iteration 476 : loss : 0.443452, loss_ce: 0.073158
# iteration 477 : loss : 0.452988, loss_ce: 0.141416
# iteration 478 : loss : 0.451767, loss_ce: 0.142969
# iteration 479 : loss : 0.453153, loss_ce: 0.109593
# iteration 480 : loss : 0.462524, loss_ce: 0.172773
# iteration 481 : loss : 0.492595, loss_ce: 0.216121
# iteration 482 : loss : 0.464225, loss_ce: 0.120833
# iteration 483 : loss : 0.460396, loss_ce: 0.098259
# iteration 484 : loss : 0.434388, loss_ce: 0.104559
# iteration 485 : loss : 0.464378, loss_ce: 0.172504
# iteration 486 : loss : 0.461160, loss_ce: 0.146349
# iteration 487 : loss : 0.456562, loss_ce: 0.121555
# iteration 488 : loss : 0.440905, loss_ce: 0.105611
# iteration 489 : loss : 0.460475, loss_ce: 0.153205
# iteration 490 : loss : 0.432920, loss_ce: 0.090095
# iteration 491 : loss : 0.429993, loss_ce: 0.111447
# iteration 492 : loss : 0.444118, loss_ce: 0.101063
# iteration 493 : loss : 0.444547, loss_ce: 0.100157
# iteration 494 : loss : 0.418536, loss_ce: 0.094345
# iteration 495 : loss : 0.436103, loss_ce: 0.100951
# iteration 496 : loss : 0.454319, loss_ce: 0.141765
# iteration 497 : loss : 0.452623, loss_ce: 0.122273
# iteration 498 : loss : 0.462741, loss_ce: 0.151242
# iteration 499 : loss : 0.452540, loss_ce: 0.139728
# iteration 500 : loss : 0.497644, loss_ce: 0.222062
# iteration 501 : loss : 0.460664, loss_ce: 0.129348
# iteration 502 : loss : 0.489421, loss_ce: 0.194119
# iteration 503 : loss : 0.443461, loss_ce: 0.122736
# iteration 504 : loss : 0.473212, loss_ce: 0.185500
# iteration 505 : loss : 0.454168, loss_ce: 0.150940
# iteration 506 : loss : 0.459513, loss_ce: 0.127548
# iteration 507 : loss : 0.487644, loss_ce: 0.189579
# iteration 508 : loss : 0.439389, loss_ce: 0.132218
# iteration 509 : loss : 0.438944, loss_ce: 0.107823
# iteration 510 : loss : 0.473254, loss_ce: 0.133477
# iteration 511 : loss : 0.445230, loss_ce: 0.097045
# iteration 512 : loss : 0.450601, loss_ce: 0.113146
# iteration 513 : loss : 0.441052, loss_ce: 0.078633
# iteration 514 : loss : 0.490973, loss_ce: 0.148945
# iteration 515 : loss : 0.474189, loss_ce: 0.149947
# iteration 516 : loss : 0.433965, loss_ce: 0.096090
# iteration 517 : loss : 0.470166, loss_ce: 0.174583
# iteration 518 : loss : 0.475276, loss_ce: 0.167462
# iteration 519 : loss : 0.445634, loss_ce: 0.133229
# iteration 520 : loss : 0.455412, loss_ce: 0.150206
# iteration 521 : loss : 0.480227, loss_ce: 0.181701
# iteration 522 : loss : 0.484058, loss_ce: 0.176084
# iteration 523 : loss : 0.436475, loss_ce: 0.134640
# iteration 524 : loss : 0.463174, loss_ce: 0.133532
# iteration 525 : loss : 0.466624, loss_ce: 0.146226
# iteration 526 : loss : 0.474042, loss_ce: 0.178172
# iteration 527 : loss : 0.473589, loss_ce: 0.192605
# iteration 528 : loss : 0.482161, loss_ce: 0.169523
# iteration 529 : loss : 0.466058, loss_ce: 0.176354
# iteration 530 : loss : 0.447529, loss_ce: 0.116129
# iteration 531 : loss : 0.535588, loss_ce: 0.286581
# iteration 532 : loss : 0.460362, loss_ce: 0.149176
# iteration 533 : loss : 0.418399, loss_ce: 0.092621
# iteration 534 : loss : 0.485026, loss_ce: 0.217304
# iteration 535 : loss : 0.457958, loss_ce: 0.174239
# iteration 536 : loss : 0.480487, loss_ce: 0.173943
# iteration 537 : loss : 0.451631, loss_ce: 0.141161
# iteration 538 : loss : 0.451297, loss_ce: 0.159991
# iteration 539 : loss : 0.457312, loss_ce: 0.120611
# iteration 540 : loss : 0.465329, loss_ce: 0.164872
# iteration 541 : loss : 0.443607, loss_ce: 0.114904
# iteration 542 : loss : 0.440282, loss_ce: 0.140351
# iteration 543 : loss : 0.441985, loss_ce: 0.153193
# iteration 544 : loss : 0.469718, loss_ce: 0.093066
# iteration 545 : loss : 0.479543, loss_ce: 0.177037
# iteration 546 : loss : 0.448237, loss_ce: 0.146068
# iteration 547 : loss : 0.477697, loss_ce: 0.159380
# iteration 548 : loss : 0.452412, loss_ce: 0.108967
# iteration 549 : loss : 0.600146, loss_ce: 0.398607
# iteration 550 : loss : 0.463577, loss_ce: 0.167351
# iteration 551 : loss : 0.488047, loss_ce: 0.207221
# iteration 552 : loss : 0.441996, loss_ce: 0.094432
# iteration 553 : loss : 0.457174, loss_ce: 0.147825
# iteration 554 : loss : 0.478417, loss_ce: 0.198835
#   1%|▍                             | 2/150 [07:56<9:46:30, 237.78s/it]
# iteration 555 : loss : 0.455986, loss_ce: 0.089313
# iteration 556 : loss : 0.430398, loss_ce: 0.102559
# iteration 557 : loss : 0.469240, loss_ce: 0.141774
# iteration 558 : loss : 0.437475, loss_ce: 0.104999
# iteration 559 : loss : 0.480369, loss_ce: 0.190415
# iteration 560 : loss : 0.457660, loss_ce: 0.157898
# iteration 561 : loss : 0.445271, loss_ce: 0.072042
# iteration 562 : loss : 0.432222, loss_ce: 0.119132
# iteration 563 : loss : 0.444107, loss_ce: 0.131487
# iteration 564 : loss : 0.447036, loss_ce: 0.098598
# iteration 565 : loss : 0.454655, loss_ce: 0.118319
# iteration 566 : loss : 0.464872, loss_ce: 0.148002
# iteration 567 : loss : 0.441194, loss_ce: 0.103758
# iteration 568 : loss : 0.448290, loss_ce: 0.133901
# iteration 569 : loss : 0.433023, loss_ce: 0.111246
# iteration 570 : loss : 0.456967, loss_ce: 0.151257
# iteration 571 : loss : 0.464473, loss_ce: 0.137799
# iteration 572 : loss : 0.461184, loss_ce: 0.163996
# iteration 573 : loss : 0.499736, loss_ce: 0.223134
# iteration 574 : loss : 0.428233, loss_ce: 0.077723
# iteration 575 : loss : 0.446512, loss_ce: 0.121366
# iteration 576 : loss : 0.438419, loss_ce: 0.100283
# iteration 577 : loss : 0.470376, loss_ce: 0.173554
# iteration 578 : loss : 0.439660, loss_ce: 0.117030
# iteration 579 : loss : 0.447721, loss_ce: 0.142095
# iteration 580 : loss : 0.443201, loss_ce: 0.083788
# iteration 581 : loss : 0.454194, loss_ce: 0.149774
# iteration 582 : loss : 0.460515, loss_ce: 0.159873
# iteration 583 : loss : 0.440981, loss_ce: 0.086492
# iteration 584 : loss : 0.452271, loss_ce: 0.162042
# iteration 585 : loss : 0.430892, loss_ce: 0.080210
# iteration 586 : loss : 0.431385, loss_ce: 0.061237
# iteration 587 : loss : 0.432643, loss_ce: 0.114046
# iteration 588 : loss : 0.476458, loss_ce: 0.173792
# iteration 589 : loss : 0.441403, loss_ce: 0.131932
# iteration 590 : loss : 0.442729, loss_ce: 0.100447
# iteration 591 : loss : 0.480622, loss_ce: 0.194663
# iteration 592 : loss : 0.425357, loss_ce: 0.100409
# iteration 593 : loss : 0.488485, loss_ce: 0.217760
# iteration 594 : loss : 0.433083, loss_ce: 0.117244
# iteration 595 : loss : 0.420278, loss_ce: 0.115164
# iteration 596 : loss : 0.435476, loss_ce: 0.096400
# iteration 597 : loss : 0.475180, loss_ce: 0.178442
# iteration 598 : loss : 0.498590, loss_ce: 0.227551
# iteration 599 : loss : 0.445284, loss_ce: 0.113926
# iteration 600 : loss : 0.430867, loss_ce: 0.108243
# iteration 601 : loss : 0.454446, loss_ce: 0.077104
# iteration 602 : loss : 0.502419, loss_ce: 0.213880
# iteration 603 : loss : 0.435163, loss_ce: 0.098945
# iteration 604 : loss : 0.422483, loss_ce: 0.098144
# iteration 605 : loss : 0.516337, loss_ce: 0.249471
# iteration 606 : loss : 0.458952, loss_ce: 0.176903
# iteration 607 : loss : 0.437196, loss_ce: 0.108244
# iteration 608 : loss : 0.411376, loss_ce: 0.075469
# iteration 609 : loss : 0.456780, loss_ce: 0.159603
# iteration 610 : loss : 0.506688, loss_ce: 0.234886
# iteration 611 : loss : 0.459107, loss_ce: 0.169646
# iteration 612 : loss : 0.447301, loss_ce: 0.143583
# iteration 613 : loss : 0.433770, loss_ce: 0.110500
# iteration 614 : loss : 0.426897, loss_ce: 0.092878
# iteration 615 : loss : 0.433808, loss_ce: 0.115887
# iteration 616 : loss : 0.431356, loss_ce: 0.077151
# iteration 617 : loss : 0.490505, loss_ce: 0.220207
# iteration 618 : loss : 0.465948, loss_ce: 0.162796
# iteration 619 : loss : 0.461439, loss_ce: 0.084428
# iteration 620 : loss : 0.432553, loss_ce: 0.113416
# iteration 621 : loss : 0.431258, loss_ce: 0.093036
# iteration 622 : loss : 0.460238, loss_ce: 0.080041
# iteration 623 : loss : 0.454189, loss_ce: 0.089296
# iteration 624 : loss : 0.473082, loss_ce: 0.159030
# iteration 625 : loss : 0.499513, loss_ce: 0.225036
# iteration 626 : loss : 0.454116, loss_ce: 0.053746
# iteration 627 : loss : 0.422452, loss_ce: 0.094238
# iteration 628 : loss : 0.534323, loss_ce: 0.256795
# iteration 629 : loss : 0.399669, loss_ce: 0.071715
# iteration 630 : loss : 0.402761, loss_ce: 0.069112
# iteration 631 : loss : 0.449628, loss_ce: 0.107652
# iteration 632 : loss : 0.434033, loss_ce: 0.122674
# iteration 633 : loss : 0.425273, loss_ce: 0.076483
# iteration 634 : loss : 0.431103, loss_ce: 0.113293
# iteration 635 : loss : 0.441236, loss_ce: 0.114432
# iteration 636 : loss : 0.406699, loss_ce: 0.093303
# iteration 637 : loss : 0.415779, loss_ce: 0.099966
# iteration 638 : loss : 0.430838, loss_ce: 0.085436
# iteration 639 : loss : 0.411556, loss_ce: 0.094974
# iteration 640 : loss : 0.485543, loss_ce: 0.199974
# iteration 641 : loss : 0.463864, loss_ce: 0.148601
# iteration 642 : loss : 0.491221, loss_ce: 0.180799
# iteration 643 : loss : 0.457552, loss_ce: 0.168831
# iteration 644 : loss : 0.426966, loss_ce: 0.109973
# iteration 645 : loss : 0.460458, loss_ce: 0.140789
# iteration 646 : loss : 0.492631, loss_ce: 0.217838
# iteration 647 : loss : 0.451518, loss_ce: 0.162296
# iteration 648 : loss : 0.438080, loss_ce: 0.120022
# iteration 649 : loss : 0.420372, loss_ce: 0.115669
# iteration 650 : loss : 0.451956, loss_ce: 0.145616
# iteration 651 : loss : 0.438476, loss_ce: 0.101822
# iteration 652 : loss : 0.489165, loss_ce: 0.197040
# iteration 653 : loss : 0.469980, loss_ce: 0.158952
# iteration 654 : loss : 0.428517, loss_ce: 0.094036
# iteration 655 : loss : 0.436932, loss_ce: 0.103884
# iteration 656 : loss : 0.452618, loss_ce: 0.134250
# iteration 657 : loss : 0.427495, loss_ce: 0.083366
# iteration 658 : loss : 0.476108, loss_ce: 0.196894
# iteration 659 : loss : 0.424272, loss_ce: 0.102766
# iteration 660 : loss : 0.453792, loss_ce: 0.170986
# iteration 661 : loss : 0.418914, loss_ce: 0.105425
# iteration 662 : loss : 0.442165, loss_ce: 0.140809
# iteration 663 : loss : 0.462279, loss_ce: 0.178942
# iteration 664 : loss : 0.458276, loss_ce: 0.152393
# iteration 665 : loss : 0.480564, loss_ce: 0.200090
# iteration 666 : loss : 0.436405, loss_ce: 0.108261
# iteration 667 : loss : 0.463009, loss_ce: 0.177255
# iteration 668 : loss : 0.431075, loss_ce: 0.137572
# iteration 669 : loss : 0.460913, loss_ce: 0.173849
# iteration 670 : loss : 0.426815, loss_ce: 0.086463
# iteration 671 : loss : 0.455489, loss_ce: 0.169447
# iteration 672 : loss : 0.430508, loss_ce: 0.111579
# iteration 673 : loss : 0.437168, loss_ce: 0.100005
# iteration 674 : loss : 0.437754, loss_ce: 0.118106
# iteration 675 : loss : 0.444752, loss_ce: 0.137448
# iteration 676 : loss : 0.458968, loss_ce: 0.148737
# iteration 677 : loss : 0.441073, loss_ce: 0.121534
# iteration 678 : loss : 0.502735, loss_ce: 0.215513
# iteration 679 : loss : 0.427187, loss_ce: 0.125457
# iteration 680 : loss : 0.448642, loss_ce: 0.135634
# iteration 681 : loss : 0.406214, loss_ce: 0.079702
# iteration 682 : loss : 0.418386, loss_ce: 0.095013
# iteration 683 : loss : 0.495109, loss_ce: 0.233005
# iteration 684 : loss : 0.428673, loss_ce: 0.123692
# iteration 685 : loss : 0.432789, loss_ce: 0.097869
# iteration 686 : loss : 0.450598, loss_ce: 0.096643
# iteration 687 : loss : 0.423745, loss_ce: 0.124839
# iteration 688 : loss : 0.433993, loss_ce: 0.136334
# iteration 689 : loss : 0.431784, loss_ce: 0.134025
# iteration 690 : loss : 0.460136, loss_ce: 0.100488
# iteration 691 : loss : 0.427712, loss_ce: 0.112096
# iteration 692 : loss : 0.423383, loss_ce: 0.118172
# iteration 693 : loss : 0.449775, loss_ce: 0.149184
# iteration 694 : loss : 0.412302, loss_ce: 0.082108
# iteration 695 : loss : 0.437611, loss_ce: 0.086690
# iteration 696 : loss : 0.449543, loss_ce: 0.151782
# iteration 697 : loss : 0.420896, loss_ce: 0.108578
# iteration 698 : loss : 0.401687, loss_ce: 0.065634
# iteration 699 : loss : 0.485105, loss_ce: 0.208217
# iteration 700 : loss : 0.427653, loss_ce: 0.083288
# iteration 701 : loss : 0.453409, loss_ce: 0.112173
# iteration 702 : loss : 0.421411, loss_ce: 0.106789
# iteration 703 : loss : 0.470401, loss_ce: 0.181300
# iteration 704 : loss : 0.438197, loss_ce: 0.118761
# iteration 705 : loss : 0.497349, loss_ce: 0.215022
# iteration 706 : loss : 0.448449, loss_ce: 0.169211
# iteration 707 : loss : 0.419932, loss_ce: 0.115316
# iteration 708 : loss : 0.425876, loss_ce: 0.128114
# iteration 709 : loss : 0.472444, loss_ce: 0.097107
# iteration 710 : loss : 0.429280, loss_ce: 0.124480
# iteration 711 : loss : 0.463169, loss_ce: 0.103979
# iteration 712 : loss : 0.426676, loss_ce: 0.102991
# iteration 713 : loss : 0.428108, loss_ce: 0.103781
# iteration 714 : loss : 0.443604, loss_ce: 0.099426
# iteration 715 : loss : 0.423741, loss_ce: 0.076707
# iteration 716 : loss : 0.433429, loss_ce: 0.060810
# iteration 717 : loss : 0.439873, loss_ce: 0.128980
# iteration 718 : loss : 0.526117, loss_ce: 0.261690
# iteration 719 : loss : 0.449136, loss_ce: 0.143336
# iteration 720 : loss : 0.409564, loss_ce: 0.079802
# iteration 721 : loss : 0.438836, loss_ce: 0.126340
# iteration 722 : loss : 0.435107, loss_ce: 0.094263
# iteration 723 : loss : 0.462420, loss_ce: 0.162065
# iteration 724 : loss : 0.482536, loss_ce: 0.208587
# iteration 725 : loss : 0.453430, loss_ce: 0.169802
# iteration 726 : loss : 0.433963, loss_ce: 0.102479
# iteration 727 : loss : 0.431480, loss_ce: 0.088810
# iteration 728 : loss : 0.461034, loss_ce: 0.097734
# iteration 729 : loss : 0.423072, loss_ce: 0.112568
# iteration 730 : loss : 0.415731, loss_ce: 0.096192
# iteration 731 : loss : 0.428430, loss_ce: 0.111009
# iteration 732 : loss : 0.490422, loss_ce: 0.218822
# iteration 733 : loss : 0.430769, loss_ce: 0.096351
# iteration 734 : loss : 0.466716, loss_ce: 0.079055
# iteration 735 : loss : 0.501739, loss_ce: 0.219244
# iteration 736 : loss : 0.458659, loss_ce: 0.157642
# iteration 737 : loss : 0.469296, loss_ce: 0.059814
# iteration 738 : loss : 0.446597, loss_ce: 0.141464
# iteration 739 : loss : 0.441377, loss_ce: 0.127739
# iteration 740 : loss : 0.434528, loss_ce: 0.068648
# iteration 741 : loss : 0.428669, loss_ce: 0.103241
# iteration 742 : loss : 0.452763, loss_ce: 0.091326
# iteration 743 : loss : 0.442417, loss_ce: 0.131897
# iteration 744 : loss : 0.455771, loss_ce: 0.164645
# iteration 745 : loss : 0.424745, loss_ce: 0.105164
# iteration 746 : loss : 0.450859, loss_ce: 0.124573
# iteration 747 : loss : 0.423691, loss_ce: 0.096151
# iteration 748 : loss : 0.450159, loss_ce: 0.149472
# iteration 749 : loss : 0.423359, loss_ce: 0.130747
# iteration 750 : loss : 0.453028, loss_ce: 0.166900
# iteration 751 : loss : 0.420989, loss_ce: 0.103850
# iteration 752 : loss : 0.464821, loss_ce: 0.104651
# iteration 753 : loss : 0.462675, loss_ce: 0.180565
# iteration 754 : loss : 0.473813, loss_ce: 0.194555
# iteration 755 : loss : 0.472363, loss_ce: 0.202391
# iteration 756 : loss : 0.453531, loss_ce: 0.171339
# iteration 757 : loss : 0.439871, loss_ce: 0.140844
# iteration 758 : loss : 0.447357, loss_ce: 0.109435
# iteration 759 : loss : 0.426587, loss_ce: 0.125692
# iteration 760 : loss : 0.451094, loss_ce: 0.155022
# iteration 761 : loss : 0.407157, loss_ce: 0.087772
# iteration 762 : loss : 0.412576, loss_ce: 0.083298
# iteration 763 : loss : 0.480704, loss_ce: 0.180527
# iteration 764 : loss : 0.445281, loss_ce: 0.113566
# iteration 765 : loss : 0.447680, loss_ce: 0.120316
# iteration 766 : loss : 0.467039, loss_ce: 0.079530
# iteration 767 : loss : 0.413550, loss_ce: 0.094321
# iteration 768 : loss : 0.413177, loss_ce: 0.086183
# iteration 769 : loss : 0.463329, loss_ce: 0.171463
# iteration 770 : loss : 0.419306, loss_ce: 0.092590
# iteration 771 : loss : 0.480074, loss_ce: 0.203661
# iteration 772 : loss : 0.440832, loss_ce: 0.138829
# iteration 773 : loss : 0.432569, loss_ce: 0.145676
# iteration 774 : loss : 0.463512, loss_ce: 0.153447
# iteration 775 : loss : 0.434990, loss_ce: 0.126477
# iteration 776 : loss : 0.421942, loss_ce: 0.104040
# iteration 777 : loss : 0.436638, loss_ce: 0.104409
# iteration 778 : loss : 0.441002, loss_ce: 0.107236
# iteration 779 : loss : 0.476284, loss_ce: 0.187485
# iteration 780 : loss : 0.455430, loss_ce: 0.146906
# iteration 781 : loss : 0.413173, loss_ce: 0.097832
# iteration 782 : loss : 0.426445, loss_ce: 0.106434
# iteration 783 : loss : 0.427978, loss_ce: 0.097401
# iteration 784 : loss : 0.417633, loss_ce: 0.061298
# iteration 785 : loss : 0.431506, loss_ce: 0.061929
# iteration 786 : loss : 0.461654, loss_ce: 0.047267
# iteration 787 : loss : 0.530091, loss_ce: 0.256553
# iteration 788 : loss : 0.476359, loss_ce: 0.186937
# iteration 789 : loss : 0.441103, loss_ce: 0.136601
# iteration 790 : loss : 0.491302, loss_ce: 0.227033
# iteration 791 : loss : 0.505424, loss_ce: 0.249079
# iteration 792 : loss : 0.442209, loss_ce: 0.095691
# iteration 793 : loss : 0.457861, loss_ce: 0.095655
# iteration 794 : loss : 0.432437, loss_ce: 0.125564
# iteration 795 : loss : 0.463497, loss_ce: 0.144141
# iteration 796 : loss : 0.438032, loss_ce: 0.134394
# iteration 797 : loss : 0.465288, loss_ce: 0.165821
# iteration 798 : loss : 0.448633, loss_ce: 0.157335
# iteration 799 : loss : 0.475064, loss_ce: 0.110676
# iteration 800 : loss : 0.462981, loss_ce: 0.188197
# iteration 801 : loss : 0.445506, loss_ce: 0.110040
# iteration 802 : loss : 0.447040, loss_ce: 0.131817
# iteration 803 : loss : 0.421596, loss_ce: 0.108423
# iteration 804 : loss : 0.480286, loss_ce: 0.209125
# iteration 805 : loss : 0.443713, loss_ce: 0.123510
# iteration 806 : loss : 0.468034, loss_ce: 0.153827
# iteration 807 : loss : 0.436143, loss_ce: 0.142514
# iteration 808 : loss : 0.452005, loss_ce: 0.150873
# iteration 809 : loss : 0.448843, loss_ce: 0.167240
# iteration 810 : loss : 0.422292, loss_ce: 0.105184
# iteration 811 : loss : 0.468327, loss_ce: 0.193265
# iteration 812 : loss : 0.420230, loss_ce: 0.119604
# iteration 813 : loss : 0.435880, loss_ce: 0.124779
# iteration 814 : loss : 0.435946, loss_ce: 0.128870
# iteration 815 : loss : 0.416815, loss_ce: 0.119335
# iteration 816 : loss : 0.413643, loss_ce: 0.085666
# iteration 817 : loss : 0.418404, loss_ce: 0.122205
# iteration 818 : loss : 0.421456, loss_ce: 0.116568
# iteration 819 : loss : 0.456189, loss_ce: 0.171076
# iteration 820 : loss : 0.485473, loss_ce: 0.198092
# iteration 821 : loss : 0.422212, loss_ce: 0.096532
# iteration 822 : loss : 0.427495, loss_ce: 0.109775
# iteration 823 : loss : 0.439610, loss_ce: 0.133433
# iteration 824 : loss : 0.449008, loss_ce: 0.180632
# iteration 825 : loss : 0.409231, loss_ce: 0.100774
# iteration 826 : loss : 0.460118, loss_ce: 0.093875
# iteration 827 : loss : 0.421228, loss_ce: 0.078800
# iteration 828 : loss : 0.428946, loss_ce: 0.105339
# iteration 829 : loss : 0.449308, loss_ce: 0.143063
# iteration 830 : loss : 0.475582, loss_ce: 0.208507
# iteration 831 : loss : 0.513311, loss_ce: 0.253707
#   2%|▌                             | 3/150 [11:52<9:40:50, 237.08s/it]
# iteration 832 : loss : 0.441623, loss_ce: 0.129826
# iteration 833 : loss : 0.474758, loss_ce: 0.207308
# iteration 834 : loss : 0.425749, loss_ce: 0.106126
# iteration 835 : loss : 0.435140, loss_ce: 0.140862
# iteration 836 : loss : 0.439850, loss_ce: 0.106674
# iteration 837 : loss : 0.431555, loss_ce: 0.139121
# iteration 838 : loss : 0.477099, loss_ce: 0.214199
# iteration 839 : loss : 0.445374, loss_ce: 0.142981
# iteration 840 : loss : 0.423630, loss_ce: 0.134337
# iteration 841 : loss : 0.431120, loss_ce: 0.123893
# iteration 842 : loss : 0.430726, loss_ce: 0.121374
# iteration 843 : loss : 0.459216, loss_ce: 0.170597
# iteration 844 : loss : 0.447233, loss_ce: 0.154203
# iteration 845 : loss : 0.415495, loss_ce: 0.098283
# iteration 846 : loss : 0.452628, loss_ce: 0.088385
# iteration 847 : loss : 0.432119, loss_ce: 0.140040
# iteration 848 : loss : 0.419727, loss_ce: 0.131542
# iteration 849 : loss : 0.394560, loss_ce: 0.082900
# iteration 850 : loss : 0.447363, loss_ce: 0.154318
# iteration 851 : loss : 0.477032, loss_ce: 0.181775
# iteration 852 : loss : 0.418369, loss_ce: 0.074649
# iteration 853 : loss : 0.408480, loss_ce: 0.085971
# iteration 854 : loss : 0.431443, loss_ce: 0.084633
# iteration 855 : loss : 0.431285, loss_ce: 0.081027
# iteration 856 : loss : 0.417796, loss_ce: 0.109561
# iteration 857 : loss : 0.447263, loss_ce: 0.152498
# iteration 858 : loss : 0.450397, loss_ce: 0.164178
# iteration 859 : loss : 0.389193, loss_ce: 0.070549
# iteration 860 : loss : 0.414700, loss_ce: 0.110728
# iteration 861 : loss : 0.388682, loss_ce: 0.080440
# iteration 862 : loss : 0.416865, loss_ce: 0.121185
# iteration 863 : loss : 0.446199, loss_ce: 0.171340
# iteration 864 : loss : 0.390127, loss_ce: 0.055124
# iteration 865 : loss : 0.419020, loss_ce: 0.114407
# iteration 866 : loss : 0.418346, loss_ce: 0.089985
# iteration 867 : loss : 0.420275, loss_ce: 0.116550
# iteration 868 : loss : 0.463414, loss_ce: 0.198499
# iteration 869 : loss : 0.458426, loss_ce: 0.101353
# iteration 870 : loss : 0.446553, loss_ce: 0.124880
# iteration 871 : loss : 0.486649, loss_ce: 0.224202
# iteration 872 : loss : 0.453168, loss_ce: 0.101397
# iteration 873 : loss : 0.480181, loss_ce: 0.200215
# iteration 874 : loss : 0.446577, loss_ce: 0.066981
# iteration 875 : loss : 0.421386, loss_ce: 0.108222
# iteration 876 : loss : 0.445907, loss_ce: 0.097694
# iteration 877 : loss : 0.427597, loss_ce: 0.110561
# iteration 878 : loss : 0.440483, loss_ce: 0.125344
# iteration 879 : loss : 0.469835, loss_ce: 0.196991
# iteration 880 : loss : 0.423545, loss_ce: 0.127439
# iteration 881 : loss : 0.445411, loss_ce: 0.159511
# iteration 882 : loss : 0.407983, loss_ce: 0.098971
# iteration 883 : loss : 0.407225, loss_ce: 0.065120
# iteration 884 : loss : 0.453671, loss_ce: 0.144721
# iteration 885 : loss : 0.418706, loss_ce: 0.119314
# iteration 886 : loss : 0.423387, loss_ce: 0.134731
# iteration 887 : loss : 0.419890, loss_ce: 0.113341
# iteration 888 : loss : 0.439550, loss_ce: 0.139898
# iteration 889 : loss : 0.450897, loss_ce: 0.170025
# iteration 890 : loss : 0.413239, loss_ce: 0.084427
# iteration 891 : loss : 0.401370, loss_ce: 0.076291
# iteration 892 : loss : 0.412960, loss_ce: 0.064116
# iteration 893 : loss : 0.407602, loss_ce: 0.085151
# iteration 894 : loss : 0.408830, loss_ce: 0.090430
# iteration 895 : loss : 0.523505, loss_ce: 0.276704
# iteration 896 : loss : 0.430284, loss_ce: 0.103683
# iteration 897 : loss : 0.443140, loss_ce: 0.071389
# iteration 898 : loss : 0.459831, loss_ce: 0.179070
# iteration 899 : loss : 0.467855, loss_ce: 0.196069
# iteration 900 : loss : 0.411140, loss_ce: 0.097723
# iteration 901 : loss : 0.529771, loss_ce: 0.299111
# iteration 902 : loss : 0.424832, loss_ce: 0.105228
# iteration 903 : loss : 0.432741, loss_ce: 0.100325
# iteration 904 : loss : 0.447566, loss_ce: 0.138301
# iteration 905 : loss : 0.436732, loss_ce: 0.149504
# iteration 906 : loss : 0.466559, loss_ce: 0.081538
# iteration 907 : loss : 0.426368, loss_ce: 0.098140
# iteration 908 : loss : 0.429315, loss_ce: 0.118762
# iteration 909 : loss : 0.425144, loss_ce: 0.072298
# iteration 910 : loss : 0.405540, loss_ce: 0.104259
# iteration 911 : loss : 0.487262, loss_ce: 0.212661
# iteration 912 : loss : 0.418492, loss_ce: 0.090930
# iteration 913 : loss : 0.420712, loss_ce: 0.120395
# iteration 914 : loss : 0.450985, loss_ce: 0.058624
# iteration 915 : loss : 0.435620, loss_ce: 0.083431
# iteration 916 : loss : 0.396893, loss_ce: 0.086981
# iteration 917 : loss : 0.439436, loss_ce: 0.064672
# ...
# iteration 24431 : loss : 0.069634, loss_ce: 0.014734
# iteration 24432 : loss : 0.124779, loss_ce: 0.022421
# iteration 24433 : loss : 0.141764, loss_ce: 0.021499
# iteration 24434 : loss : 0.079572, loss_ce: 0.040232
# iteration 24435 : loss : 0.149409, loss_ce: 0.010397
# iteration 24436 : loss : 0.047689, loss_ce: 0.024984
# iteration 24437 : loss : 0.137180, loss_ce: 0.014313
# iteration 24438 : loss : 0.100940, loss_ce: 0.016808
# iteration 24439 : loss : 0.104407, loss_ce: 0.030494
# iteration 24440 : loss : 0.125663, loss_ce: 0.042843
# iteration 24441 : loss : 0.115291, loss_ce: 0.009018
# iteration 24442 : loss : 0.219234, loss_ce: 0.023867
# iteration 24443 : loss : 0.059306, loss_ce: 0.026915
# iteration 24444 : loss : 0.107904, loss_ce: 0.024058
# iteration 24445 : loss : 0.114956, loss_ce: 0.010266
# iteration 24446 : loss : 0.072815, loss_ce: 0.044426
# iteration 24447 : loss : 0.112761, loss_ce: 0.024765
# iteration 24448 : loss : 0.058916, loss_ce: 0.031638
# iteration 24449 : loss : 0.071736, loss_ce: 0.021402
# iteration 24450 : loss : 0.060461, loss_ce: 0.021438
# iteration 24451 : loss : 0.161461, loss_ce: 0.019714
# iteration 24452 : loss : 0.105332, loss_ce: 0.013266
# iteration 24453 : loss : 0.258183, loss_ce: 0.012155
# iteration 24454 : loss : 0.143270, loss_ce: 0.015336
# iteration 24455 : loss : 0.106788, loss_ce: 0.016449
# iteration 24456 : loss : 0.072871, loss_ce: 0.036091
# iteration 24457 : loss : 0.045939, loss_ce: 0.022342
# iteration 24458 : loss : 0.189156, loss_ce: 0.012830
# iteration 24459 : loss : 0.078761, loss_ce: 0.033853
# iteration 24460 : loss : 0.126689, loss_ce: 0.036863
# iteration 24461 : loss : 0.106061, loss_ce: 0.029227
# iteration 24462 : loss : 0.055061, loss_ce: 0.021093
# iteration 24463 : loss : 0.051514, loss_ce: 0.028500
# iteration 24464 : loss : 0.046523, loss_ce: 0.025864
# iteration 24465 : loss : 0.084891, loss_ce: 0.010587
# iteration 24466 : loss : 0.070109, loss_ce: 0.015066
# iteration 24467 : loss : 0.239036, loss_ce: 0.012065
# iteration 24468 : loss : 0.180910, loss_ce: 0.013073
# iteration 24469 : loss : 0.194610, loss_ce: 0.020686
# iteration 24470 : loss : 0.202023, loss_ce: 0.020677
# iteration 24471 : loss : 0.094576, loss_ce: 0.035110
# iteration 24472 : loss : 0.047753, loss_ce: 0.005055
# iteration 24473 : loss : 0.100892, loss_ce: 0.011417
# iteration 24474 : loss : 0.090816, loss_ce: 0.024255
# iteration 24475 : loss : 0.101822, loss_ce: 0.014826
# iteration 24476 : loss : 0.193002, loss_ce: 0.004246
# iteration 24477 : loss : 0.119270, loss_ce: 0.035145
# iteration 24478 : loss : 0.079488, loss_ce: 0.028021
# iteration 24479 : loss : 0.072483, loss_ce: 0.012538
# iteration 24480 : loss : 0.054918, loss_ce: 0.021283
# iteration 24481 : loss : 0.064810, loss_ce: 0.050862
# iteration 24482 : loss : 0.098328, loss_ce: 0.009129
# iteration 24483 : loss : 0.089610, loss_ce: 0.034071
# iteration 24484 : loss : 0.061769, loss_ce: 0.028356
# iteration 24485 : loss : 0.057058, loss_ce: 0.017551
# iteration 24486 : loss : 0.107523, loss_ce: 0.013503
# iteration 24487 : loss : 0.092756, loss_ce: 0.012823
# iteration 24488 : loss : 0.350827, loss_ce: 0.002999
# iteration 24489 : loss : 0.044523, loss_ce: 0.009972
# iteration 24490 : loss : 0.088187, loss_ce: 0.018053
# iteration 24491 : loss : 0.059505, loss_ce: 0.027471
# iteration 24492 : loss : 0.176082, loss_ce: 0.014569
# iteration 24493 : loss : 0.217064, loss_ce: 0.012834
# iteration 24494 : loss : 0.061037, loss_ce: 0.025903
# iteration 24495 : loss : 0.368111, loss_ce: 0.001703
# iteration 24496 : loss : 0.096502, loss_ce: 0.007493
# iteration 24497 : loss : 0.212581, loss_ce: 0.021017
# iteration 24498 : loss : 0.095981, loss_ce: 0.017382
# iteration 24499 : loss : 0.101069, loss_ce: 0.016595
# iteration 24500 : loss : 0.045709, loss_ce: 0.017625
# iteration 24501 : loss : 0.077757, loss_ce: 0.034115
# iteration 24502 : loss : 0.291829, loss_ce: 0.002336
# iteration 24503 : loss : 0.144824, loss_ce: 0.010127
# iteration 24504 : loss : 0.044527, loss_ce: 0.023316
# iteration 24505 : loss : 0.063535, loss_ce: 0.014107
# iteration 24506 : loss : 0.097088, loss_ce: 0.014602
# iteration 24507 : loss : 0.052319, loss_ce: 0.012407
# iteration 24508 : loss : 0.056948, loss_ce: 0.018928
# iteration 24509 : loss : 0.087622, loss_ce: 0.013613
# iteration 24510 : loss : 0.065875, loss_ce: 0.023057
# iteration 24511 : loss : 0.049807, loss_ce: 0.017997
# iteration 24512 : loss : 0.067979, loss_ce: 0.015699
# iteration 24513 : loss : 0.192964, loss_ce: 0.013126
# iteration 24514 : loss : 0.337913, loss_ce: 0.001376
# iteration 24515 : loss : 0.117937, loss_ce: 0.043188
# iteration 24516 : loss : 0.036361, loss_ce: 0.016245
# iteration 24517 : loss : 0.100691, loss_ce: 0.029351
# iteration 24518 : loss : 0.063028, loss_ce: 0.030200
# iteration 24519 : loss : 0.377657, loss_ce: 0.001461
# iteration 24520 : loss : 0.090418, loss_ce: 0.023476
# iteration 24521 : loss : 0.201249, loss_ce: 0.032853
# iteration 24522 : loss : 0.043534, loss_ce: 0.015948
# iteration 24523 : loss : 0.072101, loss_ce: 0.016774
# iteration 24524 : loss : 0.117406, loss_ce: 0.012408
# iteration 24525 : loss : 0.318955, loss_ce: 0.030500
# iteration 24526 : loss : 0.154837, loss_ce: 0.017733
# iteration 24527 : loss : 0.241806, loss_ce: 0.010939
# iteration 24528 : loss : 0.044652, loss_ce: 0.025238
# iteration 24529 : loss : 0.060559, loss_ce: 0.023619
# iteration 24530 : loss : 0.075364, loss_ce: 0.022166
# iteration 24531 : loss : 0.107157, loss_ce: 0.026216
# iteration 24532 : loss : 0.094179, loss_ce: 0.041660
# iteration 24533 : loss : 0.086524, loss_ce: 0.023985
# iteration 24534 : loss : 0.118968, loss_ce: 0.034970
# iteration 24535 : loss : 0.083633, loss_ce: 0.029861
# iteration 24536 : loss : 0.157551, loss_ce: 0.019951
# iteration 24537 : loss : 0.046055, loss_ce: 0.012883
# iteration 24538 : loss : 0.076400, loss_ce: 0.020820
# iteration 24539 : loss : 0.077902, loss_ce: 0.037644
# iteration 24540 : loss : 0.044385, loss_ce: 0.015880
# iteration 24541 : loss : 0.117486, loss_ce: 0.032849
# iteration 24542 : loss : 0.051952, loss_ce: 0.036279
# iteration 24543 : loss : 0.116956, loss_ce: 0.023364
# iteration 24544 : loss : 0.069479, loss_ce: 0.019772
# iteration 24545 : loss : 0.061595, loss_ce: 0.017710
# iteration 24546 : loss : 0.049743, loss_ce: 0.024972
# iteration 24547 : loss : 0.124369, loss_ce: 0.022272
# iteration 24548 : loss : 0.113328, loss_ce: 0.012821
# iteration 24549 : loss : 0.152052, loss_ce: 0.005365
# iteration 24550 : loss : 0.057045, loss_ce: 0.026921
# iteration 24551 : loss : 0.339768, loss_ce: 0.004679
# iteration 24552 : loss : 0.054297, loss_ce: 0.027721
# iteration 24553 : loss : 0.100723, loss_ce: 0.014047
# iteration 24554 : loss : 0.136002, loss_ce: 0.010060
# iteration 24555 : loss : 0.125308, loss_ce: 0.021308
# iteration 24556 : loss : 0.197139, loss_ce: 0.021889
# iteration 24557 : loss : 0.089924, loss_ce: 0.038075
# iteration 24558 : loss : 0.095799, loss_ce: 0.024876
# iteration 24559 : loss : 0.073139, loss_ce: 0.028352
# iteration 24560 : loss : 0.234949, loss_ce: 0.010147
# iteration 24561 : loss : 0.057900, loss_ce: 0.015564
# iteration 24562 : loss : 0.104750, loss_ce: 0.011977
# iteration 24563 : loss : 0.091736, loss_ce: 0.020885
# iteration 24564 : loss : 0.166130, loss_ce: 0.009411
# iteration 24565 : loss : 0.115591, loss_ce: 0.012955
# iteration 24566 : loss : 0.100509, loss_ce: 0.016792
# iteration 24567 : loss : 0.119379, loss_ce: 0.020508
# iteration 24568 : loss : 0.072163, loss_ce: 0.017619
# iteration 24569 : loss : 0.081147, loss_ce: 0.036028
# iteration 24570 : loss : 0.060639, loss_ce: 0.018193
# iteration 24571 : loss : 0.394586, loss_ce: 0.002026
# iteration 24572 : loss : 0.128283, loss_ce: 0.016289
# iteration 24573 : loss : 0.116912, loss_ce: 0.029338
# iteration 24574 : loss : 0.096398, loss_ce: 0.029861
# iteration 24575 : loss : 0.361191, loss_ce: 0.001760
# iteration 24576 : loss : 0.057606, loss_ce: 0.026182
# iteration 24577 : loss : 0.139386, loss_ce: 0.018648
# iteration 24578 : loss : 0.060178, loss_ce: 0.011524
# iteration 24579 : loss : 0.059487, loss_ce: 0.016228
# iteration 24580 : loss : 0.058236, loss_ce: 0.017406
# iteration 24581 : loss : 0.052238, loss_ce: 0.020176
# iteration 24582 : loss : 0.079092, loss_ce: 0.032555
# iteration 24583 : loss : 0.237883, loss_ce: 0.011119
# iteration 24584 : loss : 0.084637, loss_ce: 0.025977
# iteration 24585 : loss : 0.050618, loss_ce: 0.022580
# iteration 24586 : loss : 0.117775, loss_ce: 0.011947
# iteration 24587 : loss : 0.065907, loss_ce: 0.025211
# iteration 24588 : loss : 0.189056, loss_ce: 0.005957
# iteration 24589 : loss : 0.103802, loss_ce: 0.024821
# iteration 24590 : loss : 0.096783, loss_ce: 0.013987
# iteration 24591 : loss : 0.070223, loss_ce: 0.040309
# iteration 24592 : loss : 0.106122, loss_ce: 0.029178
# iteration 24593 : loss : 0.078874, loss_ce: 0.026577
# iteration 24594 : loss : 0.088842, loss_ce: 0.021146
# iteration 24595 : loss : 0.116620, loss_ce: 0.010523
# iteration 24596 : loss : 0.095529, loss_ce: 0.008509
# iteration 24597 : loss : 0.053809, loss_ce: 0.015281
# iteration 24598 : loss : 0.091561, loss_ce: 0.017554
# iteration 24599 : loss : 0.065659, loss_ce: 0.019508
# iteration 24600 : loss : 0.180755, loss_ce: 0.018592
# iteration 24601 : loss : 0.067402, loss_ce: 0.014836
# iteration 24602 : loss : 0.112999, loss_ce: 0.012753
# iteration 24603 : loss : 0.090103, loss_ce: 0.018582
# iteration 24604 : loss : 0.140607, loss_ce: 0.007190
# iteration 24605 : loss : 0.063982, loss_ce: 0.023685
# iteration 24606 : loss : 0.139472, loss_ce: 0.015899
# iteration 24607 : loss : 0.358630, loss_ce: 0.007426
# iteration 24608 : loss : 0.083258, loss_ce: 0.030318
# iteration 24609 : loss : 0.061051, loss_ce: 0.012951
# iteration 24610 : loss : 0.185589, loss_ce: 0.011613
# iteration 24611 : loss : 0.128128, loss_ce: 0.018742
# iteration 24612 : loss : 0.100214, loss_ce: 0.024742
# iteration 24613 : loss : 0.047029, loss_ce: 0.021799
# iteration 24614 : loss : 0.098626, loss_ce: 0.028114
# iteration 24615 : loss : 0.173945, loss_ce: 0.022598
# iteration 24616 : loss : 0.139778, loss_ce: 0.029045
# iteration 24617 : loss : 0.091739, loss_ce: 0.008239
# iteration 24618 : loss : 0.068280, loss_ce: 0.021740
# iteration 24619 : loss : 0.145272, loss_ce: 0.008375
# iteration 24620 : loss : 0.123138, loss_ce: 0.014940
# iteration 24621 : loss : 0.112943, loss_ce: 0.025104
# iteration 24622 : loss : 0.084295, loss_ce: 0.006231
# iteration 24623 : loss : 0.062807, loss_ce: 0.017498
# iteration 24624 : loss : 0.068252, loss_ce: 0.023755
# iteration 24625 : loss : 0.099524, loss_ce: 0.008477
# iteration 24626 : loss : 0.187924, loss_ce: 0.007981
# iteration 24627 : loss : 0.108538, loss_ce: 0.019633
# iteration 24628 : loss : 0.069878, loss_ce: 0.026913
# iteration 24629 : loss : 0.058212, loss_ce: 0.020515
# iteration 24630 : loss : 0.078660, loss_ce: 0.020802
# iteration 24631 : loss : 0.076038, loss_ce: 0.029709
# iteration 24632 : loss : 0.238935, loss_ce: 0.007435
# iteration 24633 : loss : 0.335444, loss_ce: 0.005538
# iteration 24634 : loss : 0.065984, loss_ce: 0.025165
# iteration 24635 : loss : 0.079453, loss_ce: 0.039626
# iteration 24636 : loss : 0.055377, loss_ce: 0.021806
# iteration 24637 : loss : 0.060203, loss_ce: 0.020230
# iteration 24638 : loss : 0.047585, loss_ce: 0.013006
# iteration 24639 : loss : 0.342601, loss_ce: 0.004775
# iteration 24640 : loss : 0.103587, loss_ce: 0.017133
# iteration 24641 : loss : 0.059787, loss_ce: 0.027099
# iteration 24642 : loss : 0.058861, loss_ce: 0.016653
# iteration 24643 : loss : 0.105823, loss_ce: 0.016186
# iteration 24644 : loss : 0.151671, loss_ce: 0.014261
# iteration 24645 : loss : 0.183130, loss_ce: 0.008479
# iteration 24646 : loss : 0.119099, loss_ce: 0.021232
# iteration 24647 : loss : 0.171003, loss_ce: 0.005812
# iteration 24648 : loss : 0.201462, loss_ce: 0.008007
# iteration 24649 : loss : 0.110559, loss_ce: 0.026058
# iteration 24650 : loss : 0.193612, loss_ce: 0.016106
# iteration 24651 : loss : 0.059026, loss_ce: 0.027990
# iteration 24652 : loss : 0.053061, loss_ce: 0.026506
# iteration 24653 : loss : 0.162727, loss_ce: 0.022097
#  59%|████████████████           | 89/150 [5:51:09<4:01:31, 237.56s/it]
# iteration 24654 : loss : 0.247656, loss_ce: 0.014008
# iteration 24655 : loss : 0.083244, loss_ce: 0.033870
# iteration 24656 : loss : 0.077040, loss_ce: 0.020392
# iteration 24657 : loss : 0.240917, loss_ce: 0.006692
# iteration 24658 : loss : 0.066701, loss_ce: 0.021923
# iteration 24659 : loss : 0.042331, loss_ce: 0.020897
# iteration 24660 : loss : 0.142665, loss_ce: 0.017856
# iteration 24661 : loss : 0.232633, loss_ce: 0.005115
# iteration 24662 : loss : 0.045936, loss_ce: 0.025957
# iteration 24663 : loss : 0.073366, loss_ce: 0.035061
# iteration 24664 : loss : 0.076479, loss_ce: 0.022585
# iteration 24665 : loss : 0.095125, loss_ce: 0.035951
# iteration 24666 : loss : 0.058195, loss_ce: 0.032136
# iteration 24667 : loss : 0.060365, loss_ce: 0.018627
# iteration 24668 : loss : 0.054217, loss_ce: 0.021903
# iteration 24669 : loss : 0.053937, loss_ce: 0.019430
# iteration 24670 : loss : 0.402744, loss_ce: 0.003722
# iteration 24671 : loss : 0.101418, loss_ce: 0.025327
# iteration 24672 : loss : 0.150942, loss_ce: 0.010891
# iteration 24673 : loss : 0.242765, loss_ce: 0.013269
# iteration 24674 : loss : 0.076226, loss_ce: 0.028759
# iteration 24675 : loss : 0.076295, loss_ce: 0.012028
# iteration 24676 : loss : 0.041229, loss_ce: 0.012166
# iteration 24677 : loss : 0.101733, loss_ce: 0.024330
# iteration 24678 : loss : 0.052036, loss_ce: 0.033356
# iteration 24679 : loss : 0.189046, loss_ce: 0.008827
# iteration 24680 : loss : 0.190788, loss_ce: 0.020841
# iteration 24681 : loss : 0.101159, loss_ce: 0.021544
# iteration 24682 : loss : 0.057435, loss_ce: 0.010155
# iteration 24683 : loss : 0.065121, loss_ce: 0.016625
# iteration 24684 : loss : 0.170424, loss_ce: 0.010652
# iteration 24685 : loss : 0.055651, loss_ce: 0.025669
# iteration 24686 : loss : 0.099421, loss_ce: 0.010632
# iteration 24687 : loss : 0.067406, loss_ce: 0.028711
# iteration 24688 : loss : 0.340821, loss_ce: 0.002524
# iteration 24689 : loss : 0.092848, loss_ce: 0.005650
# iteration 24690 : loss : 0.054058, loss_ce: 0.012554
# iteration 24691 : loss : 0.144681, loss_ce: 0.008410
# iteration 24692 : loss : 0.138197, loss_ce: 0.020325
# iteration 24693 : loss : 0.147392, loss_ce: 0.009165
# iteration 24694 : loss : 0.094453, loss_ce: 0.008160
# iteration 24695 : loss : 0.100210, loss_ce: 0.020474
# iteration 24696 : loss : 0.053167, loss_ce: 0.016161
# iteration 24697 : loss : 0.048983, loss_ce: 0.024939
# iteration 24698 : loss : 0.146644, loss_ce: 0.017332
# iteration 24699 : loss : 0.109228, loss_ce: 0.015248
# iteration 24700 : loss : 0.243601, loss_ce: 0.016532
# iteration 24701 : loss : 0.064583, loss_ce: 0.013883
# iteration 24702 : loss : 0.083202, loss_ce: 0.022541
# iteration 24703 : loss : 0.095925, loss_ce: 0.007439
# iteration 24704 : loss : 0.097890, loss_ce: 0.022493
# iteration 24705 : loss : 0.036524, loss_ce: 0.020474
# iteration 24706 : loss : 0.082214, loss_ce: 0.052009
# iteration 24707 : loss : 0.071279, loss_ce: 0.030232
# iteration 24708 : loss : 0.099745, loss_ce: 0.019678
# iteration 24709 : loss : 0.109992, loss_ce: 0.013662
# iteration 24710 : loss : 0.091520, loss_ce: 0.018408
# iteration 24711 : loss : 0.098614, loss_ce: 0.022209
# iteration 24712 : loss : 0.094229, loss_ce: 0.009728
# iteration 24713 : loss : 0.087908, loss_ce: 0.017222
# iteration 24714 : loss : 0.063375, loss_ce: 0.026037
# iteration 24715 : loss : 0.050537, loss_ce: 0.022565
# iteration 24716 : loss : 0.063169, loss_ce: 0.022311
# iteration 24717 : loss : 0.151387, loss_ce: 0.022852
# iteration 24718 : loss : 0.053066, loss_ce: 0.015730
# iteration 24719 : loss : 0.046921, loss_ce: 0.028430
# iteration 24720 : loss : 0.060558, loss_ce: 0.018280
# iteration 24721 : loss : 0.048240, loss_ce: 0.020721
# iteration 24722 : loss : 0.052391, loss_ce: 0.016051
# iteration 24723 : loss : 0.104039, loss_ce: 0.017462
# iteration 24724 : loss : 0.305275, loss_ce: 0.005165
# iteration 24725 : loss : 0.187740, loss_ce: 0.004606
# iteration 24726 : loss : 0.104709, loss_ce: 0.017420
# iteration 24727 : loss : 0.092541, loss_ce: 0.011921
# iteration 24728 : loss : 0.045176, loss_ce: 0.018995
# iteration 24729 : loss : 0.078308, loss_ce: 0.030286
# iteration 24730 : loss : 0.092711, loss_ce: 0.035097

# %%
from torchinfo import summary

summary(net, (1,3,224,224))
# Out:
# ========================================================================================================================
# Layer (type:depth-idx)                                                 Output Shape              Param #
# ========================================================================================================================
# VisionTransformer                                                      --                        --
# ├─Transformer: 1                                                       --                        --
# │    └─Encoder: 2                                                      --                        --
# │    │    └─ModuleList: 3-1                                            --                        85,054,464
# ├─DecoderCup: 1                                                        --                        --
# │    └─ModuleList: 2-1                                                 --                        --
# ├─Transformer: 1-1                                                     [1, 196, 768]             --
# │    └─Embeddings: 2-2                                                 [1, 196, 768]             --
# │    │    └─ResNetV2: 3-2                                              [1, 1024, 14, 14]         14,770,712
# │    │    └─Conv2d: 3-3                                                [1, 768, 14, 14]          787,200
# │    │    └─Dropout: 3-4                                               [1, 196, 768]             --
# │    └─Encoder: 2-3                                                    [1, 196, 768]             --
# │    │    └─LayerNorm: 3-5                                             [1, 196, 768]             1,536
# ├─DecoderCup: 1-2                                                      [1, 16, 224, 224]         --
# │    └─Conv2dReLU: 2-4                                                 [1, 512, 14, 14]          --
# │    │    └─Conv2d: 3-6                                                [1, 512, 14, 14]          3,538,944
# │    │    └─BatchNorm2d: 3-7                                           [1, 512, 14, 14]          1,024
# │    │    └─ReLU: 3-8                                                  [1, 512, 14, 14]          --
# │    └─ModuleList: 2-1                                                 --                        --
# │    │    └─DecoderBlock: 3-9                                          [1, 256, 28, 28]          3,117,325
# │    │    └─DecoderBlock: 3-10                                         [1, 128, 56, 56]          781,277
# │    │    └─DecoderBlock: 3-11                                         [1, 64, 112, 112]         156,417
# │    │    └─DecoderBlock: 3-12                                         [1, 16, 224, 224]         14,453
# ├─SegmentationHead: 1-3                                                [1, 9, 224, 224]          --
# │    └─Conv2d: 2-5                                                     [1, 9, 224, 224]          1,305
# │    └─Identity: 2-6                                                   [1, 9, 224, 224]          --
# ========================================================================================================================
# Total params: 108,218,621
# Trainable params: 108,218,621
# Non-trainable params: 0
# Total mult-adds (G): 11.98
# ========================================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 419.29
# Params size (MB): 432.87
# Estimated Total Size (MB): 852.77
# ========================================================================================================================
